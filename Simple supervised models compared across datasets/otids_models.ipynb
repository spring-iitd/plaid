# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_text, export_graphviz
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
data_folder = '/kaggle/input/otids-can/'
print(os.listdir(data_folder))
# Out:
# ['Impersonation_attack_dataset.txt', 'Attack_free_dataset.txt', 'DoS_attack_dataset.txt', 'Fuzzy_attack_dataset.txt']

# %%
dos_data_path = os.path.join(data_folder, 'DoS_attack_dataset.txt')
benign_data_path = os.path.join(data_folder, 'Attack_free_dataset.txt')
fuzzy_data_path = os.path.join(data_folder, 'Fuzzy_attack_dataset.txt')
impersonation_data_path = os.path.join(data_folder, 'Impersonation_attack_dataset.txt')

# %%
def hex_to_bin(hex_num):
    
    binary_value = bin(int(str(hex_num), 16))[2:]
    
    return binary_value

def int_to_bin(int_num):
    
    binary_value = bin(int_num)[2:]
    
    return binary_value

def pad(value, length):
    
    curr_length = len(str(value))
    
    zeros = '0' * (length - curr_length)
    
    return zeros + value

hex_to_dec = lambda x: int(x, 16)

# %%
## Since there are varying DLCs (2,5,6,8) in order to maintain data integrity
## The data must be padded with 00s when DLC < 8

def shift_columns(df):
    
    for dlc in [2,5,6]:

        df.loc[df['dlc'] == dlc, df.columns[3:]] = df.loc[df['dlc'] == dlc, df.columns[3:]].shift(periods=8-dlc, axis='columns', fill_value='00')

    return df

# %%
def read_txt_data(data_path):

    timestamps = []
    ids = []
    dlcs = []
    data = []

    # Read the data from the file
    with open(data_path, 'r') as file:
        for line in file:
            
            # Extract information from each line
            line = line.strip()
            ts = line.split("Timestamp: ")[1].strip().split(' ')[0]
            can_id = line.split('ID: ')[1].split()[0]
            dlc = line.split('DLC: ')[1].split()[0]
            can_data = ''.join(line.split('DLC: ')[-1].split()[-8:])

            #Converting Hexadecimal entries to decimal format
            timestamps.append(float(ts))
            ids.append(hex_to_dec(can_id))
            dlcs.append(int(dlc))
            data.append(hex_to_dec(can_data))

        df = pd.DataFrame({
        'timestamp': timestamps,
        'can_id': ids,
        'dlc': dlcs,
        'data': data
    })
    
    ##Sorting dataframe by timestamp
    df.sort_values(by = ['timestamp'], inplace = True)
    
    ## Creating IAT column
    df = df.assign(IAT=df['timestamp'].diff().fillna(0))
    return df

# %%
##Reading datasets
dos_data = read_txt_data(dos_data_path)
benign_data = read_txt_data(benign_data_path)
fuzzy_data = read_txt_data(fuzzy_data_path)
impersonation_data = read_txt_data(impersonation_data_path)

# %%
#Timestamps on the impersonation dataset do not start with 0, thus normalizing timestamps with respect to first datapoints
impersonation_data['timestamp'] = impersonation_data['timestamp'] - impersonation_data['timestamp'].iloc[0]

# %%
##LABELS FOR DATAPOINTS

## Benign -> 0
## DOS -> 1
## Fuzzy -> 2
## Impersonation -> 3

# %%
## Setting the labels
benign_data['label'] = 0
dos_data['label'] = dos_data['can_id'].apply(lambda x : 1 if x == 0 else 1)

## In these two datasets, entries past the 250 sec mark have attacks and benign datapoints.
## No specific labels after that, so we label all of them as attacks which will cause some mislabelling, which is reflected in the results
fuzzy_data['label'] = fuzzy_data['timestamp'].apply(lambda x : 2 if x >= 250 else 0)
impersonation_data['label'] = impersonation_data['timestamp'].apply(lambda x : 3 if x >= 250 else 0)

# %%
all_data = pd.concat([dos_data, benign_data, fuzzy_data, impersonation_data], axis=0, ignore_index=True)
all_data.drop(columns = ['timestamp'], inplace=True, axis=1)

# %%
## Number of datapoints by label
all_data['label'].value_counts()
# Out:
# 0    3333261
# 1     656579
# 3     479889
# 2     143710
# Name: label, dtype: int64

# %%
X = all_data.drop(columns = ['label'])
y = all_data['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape)
# Out:
# (3690751, 4)

# %%
print(X_test.shape)
# Out:
# (922688, 4)

# %%
y_train.value_counts()
# Out:
# 0    2666963
# 1     525096
# 3     383939
# 2     114753
# Name: label, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    666589
# 1    131364
# 3     95929
# 2     28806
# Name: label, dtype: int64

# %%
## Function to create sequences for datapoints for LSTM model
def sequencify(dataset, target, start, end, window):
  
    X = []
    y = []
    
    start = start + window 
    if end is None:
        end = len(dataset)
        
    for i in tqdm(range(start, end+1)):
        indices = range(i-window, i) 
        X.append(dataset[indices])
        
        indicey = i -1
        y.append(target[indicey])
			
    return np.array(X), np.array(y)

# %%
## Normalizing data

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
##MLP

print("-----MLP-------")

mlp = Sequential()
mlp.add(Input(shape = (4)))
mlp.add(Dense(128, activation = 'relu'))
mlp.add(Dense(128, activation = 'relu'))
mlp.add(Dense(4))

mlp.compile(optimizer='adam',
                loss=SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

es = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True)

mlp_hist = mlp.fit(X_train, y_train, epochs=100, callbacks = [es], validation_split=0.2, batch_size = 4096)

##MLP
print("-----MLP-------")

mlp_preds = mlp.predict(X_test)
mlp_preds = mlp_preds.argmax(axis = 1)

print("ACCURACY: ", accuracy_score(y_test, mlp_preds))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, mlp_preds))
# Out:
# -----MLP-------
# Epoch 1/100
# 721/721 [==============================] - 9s 6ms/step - loss: 0.6868 - accuracy: 0.7862 - val_loss: 0.6440 - val_accuracy: 0.7936
# Epoch 2/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.6364 - accuracy: 0.7937 - val_loss: 0.6267 - val_accuracy: 0.7935
# Epoch 3/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.6194 - accuracy: 0.7944 - val_loss: 0.6122 - val_accuracy: 0.7956
# Epoch 4/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.6064 - accuracy: 0.7977 - val_loss: 0.6002 - val_accuracy: 0.7992
# Epoch 5/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5979 - accuracy: 0.7993 - val_loss: 0.5954 - val_accuracy: 0.7991
# Epoch 6/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5910 - accuracy: 0.8000 - val_loss: 0.5871 - val_accuracy: 0.8005
# Epoch 7/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5854 - accuracy: 0.8004 - val_loss: 0.5819 - val_accuracy: 0.8005
# Epoch 8/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5814 - accuracy: 0.8007 - val_loss: 0.5775 - val_accuracy: 0.8011
# Epoch 9/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5778 - accuracy: 0.8010 - val_loss: 0.5762 - val_accuracy: 0.8006
# Epoch 10/100
# 721/721 [==============================] - 4s 5ms/step - loss: 0.5744 - accuracy: 0.8014 - val_loss: 0.5704 - val_accuracy: 0.8021
# Epoch 11/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5715 - accuracy: 0.8018 - val_loss: 0.5694 - val_accuracy: 0.8025
# Epoch 12/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5678 - accuracy: 0.8021 - val_loss: 0.5642 - val_accuracy: 0.8028
# Epoch 13/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5648 - accuracy: 0.8022 - val_loss: 0.5621 - val_accuracy: 0.8028
# Epoch 14/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5619 - accuracy: 0.8025 - val_loss: 0.5587 - val_accuracy: 0.8034
# Epoch 15/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5585 - accuracy: 0.8029 - val_loss: 0.5548 - val_accuracy: 0.8036
# Epoch 16/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5565 - accuracy: 0.8031 - val_loss: 0.5531 - val_accuracy: 0.8032
# Epoch 17/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5546 - accuracy: 0.8032 - val_loss: 0.5545 - val_accuracy: 0.8026
# Epoch 18/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5525 - accuracy: 0.8032 - val_loss: 0.5510 - val_accuracy: 0.8031
# Epoch 19/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5499 - accuracy: 0.8035 - val_loss: 0.5498 - val_accuracy: 0.8034
# Epoch 20/100
# 721/721 [==============================] - 4s 6ms/step - loss: 0.5490 - accuracy: 0.8035 - val_loss: 0.5495 - val_accuracy: 0.8034
# Epoch 21/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5468 - accuracy: 0.8036 - val_loss: 0.5456 - val_accuracy: 0.8042
# Epoch 22/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5447 - accuracy: 0.8039 - val_loss: 0.5417 - val_accuracy: 0.8047
# Epoch 23/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5435 - accuracy: 0.8039 - val_loss: 0.5423 - val_accuracy: 0.8036
# Epoch 24/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5422 - accuracy: 0.8040 - val_loss: 0.5424 - val_accuracy: 0.8046
# Epoch 25/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5405 - accuracy: 0.8040 - val_loss: 0.5409 - val_accuracy: 0.8045
# Epoch 26/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5404 - accuracy: 0.8041 - val_loss: 0.5375 - val_accuracy: 0.8047
# Epoch 27/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5391 - accuracy: 0.8041 - val_loss: 0.5376 - val_accuracy: 0.8025
# Epoch 28/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5383 - accuracy: 0.8042 - val_loss: 0.5360 - val_accuracy: 0.8049
# Epoch 29/100
# 721/721 [==============================] - 4s 6ms/step - loss: 0.5371 - accuracy: 0.8041 - val_loss: 0.5357 - val_accuracy: 0.8045
# Epoch 30/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.8043 - val_loss: 0.5372 - val_accuracy: 0.8046
# Epoch 31/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5352 - accuracy: 0.8044 - val_loss: 0.5344 - val_accuracy: 0.8034
# Epoch 32/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5350 - accuracy: 0.8045 - val_loss: 0.5345 - val_accuracy: 0.8043
# Epoch 33/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5341 - accuracy: 0.8046 - val_loss: 0.5319 - val_accuracy: 0.8053
# Epoch 34/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5331 - accuracy: 0.8046 - val_loss: 0.5349 - val_accuracy: 0.8044
# Epoch 35/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5328 - accuracy: 0.8047 - val_loss: 0.5335 - val_accuracy: 0.8046
# Epoch 36/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5323 - accuracy: 0.8046 - val_loss: 0.5305 - val_accuracy: 0.8056
# Epoch 37/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5320 - accuracy: 0.8048 - val_loss: 0.5332 - val_accuracy: 0.8040
# Epoch 38/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5308 - accuracy: 0.8052 - val_loss: 0.5293 - val_accuracy: 0.8059
# Epoch 39/100
# 721/721 [==============================] - 4s 5ms/step - loss: 0.5307 - accuracy: 0.8051 - val_loss: 0.5296 - val_accuracy: 0.8062
# Epoch 40/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5308 - accuracy: 0.8049 - val_loss: 0.5300 - val_accuracy: 0.8040
# Epoch 41/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5296 - accuracy: 0.8052 - val_loss: 0.5273 - val_accuracy: 0.8046
# Epoch 42/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5288 - accuracy: 0.8053 - val_loss: 0.5313 - val_accuracy: 0.8041
# Epoch 43/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5294 - accuracy: 0.8052 - val_loss: 0.5311 - val_accuracy: 0.8067
# Epoch 44/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5287 - accuracy: 0.8054 - val_loss: 0.5290 - val_accuracy: 0.8060
# Epoch 45/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5281 - accuracy: 0.8055 - val_loss: 0.5329 - val_accuracy: 0.8056
# Epoch 46/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5274 - accuracy: 0.8056 - val_loss: 0.5265 - val_accuracy: 0.8061
# Epoch 47/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5279 - accuracy: 0.8055 - val_loss: 0.5260 - val_accuracy: 0.8072
# Epoch 48/100
# 721/721 [==============================] - 4s 5ms/step - loss: 0.5267 - accuracy: 0.8057 - val_loss: 0.5280 - val_accuracy: 0.8059
# Epoch 49/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5273 - accuracy: 0.8058 - val_loss: 0.5273 - val_accuracy: 0.8042
# Epoch 50/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5262 - accuracy: 0.8059 - val_loss: 0.5307 - val_accuracy: 0.8050
# Epoch 51/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5259 - accuracy: 0.8060 - val_loss: 0.5255 - val_accuracy: 0.8066
# Epoch 52/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5260 - accuracy: 0.8060 - val_loss: 0.5269 - val_accuracy: 0.8064
# Epoch 53/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5252 - accuracy: 0.8062 - val_loss: 0.5256 - val_accuracy: 0.8051
# Epoch 54/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5252 - accuracy: 0.8063 - val_loss: 0.5284 - val_accuracy: 0.8059
# Epoch 55/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5246 - accuracy: 0.8064 - val_loss: 0.5237 - val_accuracy: 0.8061
# Epoch 56/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5252 - accuracy: 0.8063 - val_loss: 0.5276 - val_accuracy: 0.8067
# Epoch 57/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5245 - accuracy: 0.8063 - val_loss: 0.5218 - val_accuracy: 0.8063
# Epoch 58/100
# 721/721 [==============================] - 4s 6ms/step - loss: 0.5241 - accuracy: 0.8065 - val_loss: 0.5232 - val_accuracy: 0.8065
# Epoch 59/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5243 - accuracy: 0.8064 - val_loss: 0.5228 - val_accuracy: 0.8073
# Epoch 60/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5237 - accuracy: 0.8066 - val_loss: 0.5250 - val_accuracy: 0.8067
# Epoch 61/100
# 721/721 [==============================] - 3s 4ms/step - loss: 0.5240 - accuracy: 0.8067 - val_loss: 0.5219 - val_accuracy: 0.8075
# Epoch 62/100
# 721/721 [==============================] - 3s 5ms/step - loss: 0.5231 - accuracy: 0.8067 - val_loss: 0.5231 - val_accuracy: 0.8068
# -----MLP-------
# Exception ignored in: <function _xla_gc_callback at 0x790413f18e50>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 28834/28834 [==============================] - 50s 2ms/step
# ACCURACY:  0.8060406117777623
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88    666589
#            1       0.83      0.69      0.76    131364
#            2       0.32      0.00      0.01     28806
#            3       0.50      0.04      0.08     95929
#
#     accuracy                           0.81    922688
#    macro avg       0.61      0.43      0.43    922688
# weighted avg       0.76      0.81      0.75    922688

# %%
plt.plot(mlp_hist.history['loss'], label = 'Loss')
plt.plot(mlp_hist.history['val_loss'], label = 'Validation Loss')
plt.title('MLP Loss and Validation Loss Curves')

plt.legend(loc = 'best')
plt.show()

# %%
X_train_seq, y_train_seq = sequencify(X_train, y_train.values, start = 0, end = None, window = 10)
print(X_train_seq.shape, y_train_seq.shape)

print(type(X_train_seq))
# Out:
# 100%|██████████| 3690742/3690742 [00:38<00:00, 96242.66it/s]
# (3690742, 10, 4) (3690742,)
# <class 'numpy.ndarray'>

# %%
X_test_seq, y_test_seq = sequencify(X_test, y_test.values, start = 0, end = None, window = 10)
print(X_test_seq.shape, y_test_seq.shape)
# Out:
# 100%|██████████| 922679/922679 [00:10<00:00, 89487.84it/s]
# (922679, 10, 4) (922679,)

# %%
##LSTM

print("-----LSTM-------")

lstm = Sequential()

lstm.add(Input(shape = X_train_seq.shape[1:]))
lstm.add(LSTM(128, activation = 'relu'))
lstm.add(Dense(4, activation = 'softmax'))

lstm.compile(
    loss = SparseCategoricalCrossentropy(from_logits = False),
    optimizer = Adam(learning_rate = 0.001),
    metrics = ['accuracy'])

es = EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

lstm_hist = lstm.fit(X_train_seq, y_train_seq, batch_size = 1024, validation_split = 0.2,
        callbacks = [es], epochs = 1000)

print("-----LSTM-------")

lstm_preds = lstm.predict(X_test_seq, batch_size = 1024)
lstm_preds = lstm_preds.argmax(axis = 1)

print("ACCURACY: ", accuracy_score(y_test_seq, lstm_preds))
print("CLASSIFICATION REPORT:\n", classification_report(y_test_seq, lstm_preds))
# Out:
# -----LSTM-------
# Epoch 1/1000
# 2884/2884 [==============================] - 78s 26ms/step - loss: 0.6950 - accuracy: 0.7866 - val_loss: 0.6552 - val_accuracy: 0.7940
# Epoch 2/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.6498 - accuracy: 0.7944 - val_loss: 0.6439 - val_accuracy: 0.7950
# Epoch 3/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.6398 - accuracy: 0.7950 - val_loss: 0.6355 - val_accuracy: 0.7951
# Epoch 4/1000
# 2884/2884 [==============================] - 76s 27ms/step - loss: 0.6319 - accuracy: 0.7953 - val_loss: 0.6283 - val_accuracy: 0.7955
# Epoch 5/1000
# 2884/2884 [==============================] - 76s 27ms/step - loss: 0.6265 - accuracy: 0.7955 - val_loss: 0.6238 - val_accuracy: 0.7955
# Epoch 6/1000
# 2884/2884 [==============================] - 80s 28ms/step - loss: 0.6228 - accuracy: 0.7956 - val_loss: 0.6204 - val_accuracy: 0.7959
# Epoch 7/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.6199 - accuracy: 0.7959 - val_loss: 0.6181 - val_accuracy: 0.7958
# Epoch 8/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.6177 - accuracy: 0.7961 - val_loss: 0.6162 - val_accuracy: 0.7960
# Epoch 9/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.6152 - accuracy: 0.7964 - val_loss: 0.6138 - val_accuracy: 0.7969
# Epoch 10/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.6125 - accuracy: 0.7968 - val_loss: 0.6105 - val_accuracy: 0.7968
# Epoch 11/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.6106 - accuracy: 0.7971 - val_loss: 0.6095 - val_accuracy: 0.7966
# Epoch 12/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.6086 - accuracy: 0.7973 - val_loss: 0.6082 - val_accuracy: 0.7969
# Epoch 13/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.6065 - accuracy: 0.7975 - val_loss: 0.6063 - val_accuracy: 0.7976
# Epoch 14/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.6044 - accuracy: 0.7977 - val_loss: 0.6026 - val_accuracy: 0.7978
# Epoch 15/1000
# 2884/2884 [==============================] - 79s 28ms/step - loss: 0.6020 - accuracy: 0.7980 - val_loss: 0.6011 - val_accuracy: 0.7978
# Epoch 16/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5999 - accuracy: 0.7983 - val_loss: 0.6016 - val_accuracy: 0.7992
# Epoch 17/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5977 - accuracy: 0.7985 - val_loss: 0.5985 - val_accuracy: 0.7976
# Epoch 18/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5956 - accuracy: 0.7988 - val_loss: 0.5944 - val_accuracy: 0.7986
# Epoch 19/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5937 - accuracy: 0.7990 - val_loss: 0.5929 - val_accuracy: 0.7992
# Epoch 20/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5918 - accuracy: 0.7993 - val_loss: 0.5913 - val_accuracy: 0.7992
# Epoch 21/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5900 - accuracy: 0.7995 - val_loss: 0.5886 - val_accuracy: 0.7995
# Epoch 22/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5882 - accuracy: 0.7997 - val_loss: 0.5868 - val_accuracy: 0.7999
# Epoch 23/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5862 - accuracy: 0.7998 - val_loss: 0.5854 - val_accuracy: 0.7989
# Epoch 24/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5846 - accuracy: 0.8000 - val_loss: 0.5835 - val_accuracy: 0.8001
# Epoch 25/1000
# 2884/2884 [==============================] - 76s 27ms/step - loss: 0.5832 - accuracy: 0.8000 - val_loss: 0.5823 - val_accuracy: 0.8004
# Epoch 26/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5818 - accuracy: 0.8001 - val_loss: 0.5833 - val_accuracy: 0.7998
# Epoch 27/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5804 - accuracy: 0.8003 - val_loss: 0.5792 - val_accuracy: 0.8010
# Epoch 28/1000
# 2884/2884 [==============================] - 72s 25ms/step - loss: 0.5789 - accuracy: 0.8005 - val_loss: 0.5793 - val_accuracy: 0.8001
# Epoch 29/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5774 - accuracy: 0.8007 - val_loss: 0.5775 - val_accuracy: 0.8003
# Epoch 30/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5761 - accuracy: 0.8009 - val_loss: 0.5754 - val_accuracy: 0.8001
# Epoch 31/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5749 - accuracy: 0.8009 - val_loss: 0.5763 - val_accuracy: 0.8013
# Epoch 32/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5739 - accuracy: 0.8010 - val_loss: 0.5737 - val_accuracy: 0.8009
# Epoch 33/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5734 - accuracy: 0.8011 - val_loss: 0.5732 - val_accuracy: 0.8010
# Epoch 34/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5725 - accuracy: 0.8012 - val_loss: 0.5730 - val_accuracy: 0.8005
# Epoch 35/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5714 - accuracy: 0.8013 - val_loss: 0.5740 - val_accuracy: 0.7997
# Epoch 36/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5708 - accuracy: 0.8014 - val_loss: 0.5718 - val_accuracy: 0.8009
# Epoch 37/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5703 - accuracy: 0.8014 - val_loss: 0.5731 - val_accuracy: 0.8019
# Epoch 38/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5698 - accuracy: 0.8015 - val_loss: 0.5716 - val_accuracy: 0.8006
# Epoch 39/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5699 - accuracy: 0.8015 - val_loss: 0.5721 - val_accuracy: 0.8005
# Epoch 40/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5684 - accuracy: 0.8017 - val_loss: 0.5701 - val_accuracy: 0.8005
# Epoch 41/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5679 - accuracy: 0.8017 - val_loss: 0.5713 - val_accuracy: 0.8013
# Epoch 42/1000
# 2884/2884 [==============================] - 72s 25ms/step - loss: 0.5677 - accuracy: 0.8017 - val_loss: 0.5689 - val_accuracy: 0.8017
# Epoch 43/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5670 - accuracy: 0.8018 - val_loss: 0.5685 - val_accuracy: 0.8015
# Epoch 44/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5665 - accuracy: 0.8018 - val_loss: 0.5693 - val_accuracy: 0.8012
# Epoch 45/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5657 - accuracy: 0.8018 - val_loss: 0.5676 - val_accuracy: 0.8014
# Epoch 46/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5653 - accuracy: 0.8018 - val_loss: 0.5690 - val_accuracy: 0.8014
# Epoch 47/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5650 - accuracy: 0.8019 - val_loss: 0.5675 - val_accuracy: 0.8014
# Epoch 48/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5643 - accuracy: 0.8018 - val_loss: 0.5680 - val_accuracy: 0.8003
# Epoch 49/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5638 - accuracy: 0.8019 - val_loss: 0.5670 - val_accuracy: 0.8007
# Epoch 50/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5634 - accuracy: 0.8020 - val_loss: 0.5672 - val_accuracy: 0.8009
# Epoch 51/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5628 - accuracy: 0.8020 - val_loss: 0.5664 - val_accuracy: 0.8014
# Epoch 52/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5622 - accuracy: 0.8020 - val_loss: 0.5660 - val_accuracy: 0.8010
# Epoch 53/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5619 - accuracy: 0.8018 - val_loss: 0.5674 - val_accuracy: 0.8011
# Epoch 54/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5625 - accuracy: 0.8019 - val_loss: 0.5660 - val_accuracy: 0.8002
# Epoch 55/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5611 - accuracy: 0.8019 - val_loss: 0.5674 - val_accuracy: 0.7999
# Epoch 56/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5605 - accuracy: 0.8019 - val_loss: 0.5656 - val_accuracy: 0.8005
# Epoch 57/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5613 - accuracy: 0.8018 - val_loss: 0.5656 - val_accuracy: 0.8011
# Epoch 58/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5602 - accuracy: 0.8019 - val_loss: 0.5657 - val_accuracy: 0.8007
# Epoch 59/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5595 - accuracy: 0.8019 - val_loss: 0.5654 - val_accuracy: 0.7999
# Epoch 60/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5592 - accuracy: 0.8019 - val_loss: 0.5653 - val_accuracy: 0.8011
# Epoch 61/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5594 - accuracy: 0.8020 - val_loss: 0.5642 - val_accuracy: 0.7989
# Epoch 62/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5586 - accuracy: 0.8020 - val_loss: 0.5651 - val_accuracy: 0.8007
# Epoch 63/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5574 - accuracy: 0.8020 - val_loss: 0.5651 - val_accuracy: 0.8010
# Epoch 64/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5574 - accuracy: 0.8020 - val_loss: 0.5662 - val_accuracy: 0.7988
# Epoch 65/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5567 - accuracy: 0.8021 - val_loss: 0.5647 - val_accuracy: 0.8002
# Epoch 66/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5603 - accuracy: 0.8018 - val_loss: 0.5659 - val_accuracy: 0.8006
# Epoch 68/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5590 - accuracy: 0.8019 - val_loss: 0.5665 - val_accuracy: 0.8004
# Epoch 69/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5617 - accuracy: 0.8016 - val_loss: 0.5637 - val_accuracy: 0.8006
# Epoch 70/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5573 - accuracy: 0.8020 - val_loss: 0.5658 - val_accuracy: 0.8001
# Epoch 71/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5558 - accuracy: 0.8021 - val_loss: 0.5639 - val_accuracy: 0.7991
# Epoch 72/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5582 - accuracy: 0.8020 - val_loss: 0.5658 - val_accuracy: 0.8001
# Epoch 73/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5577 - accuracy: 0.8020 - val_loss: 0.5649 - val_accuracy: 0.7996
# Epoch 74/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5571 - accuracy: 0.8021 - val_loss: 0.5669 - val_accuracy: 0.8009
# Epoch 75/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5601 - accuracy: 0.8018 - val_loss: 0.5633 - val_accuracy: 0.7999
# Epoch 76/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5555 - accuracy: 0.8021 - val_loss: 0.5628 - val_accuracy: 0.7999
# Epoch 77/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5551 - accuracy: 0.8022 - val_loss: 0.5630 - val_accuracy: 0.8005
# Epoch 78/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5563 - accuracy: 0.8021 - val_loss: 0.5666 - val_accuracy: 0.7995
# Epoch 79/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5570 - accuracy: 0.8021 - val_loss: 0.5688 - val_accuracy: 0.7993
# Epoch 80/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5576 - accuracy: 0.8018 - val_loss: 0.5615 - val_accuracy: 0.8006
# Epoch 81/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5570 - accuracy: 0.8019 - val_loss: 0.5639 - val_accuracy: 0.8007
# Epoch 82/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5606 - accuracy: 0.8021 - val_loss: 0.5611 - val_accuracy: 0.8011
# Epoch 83/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5571 - accuracy: 0.8021 - val_loss: 0.5628 - val_accuracy: 0.8013
# Epoch 84/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5571 - accuracy: 0.8021 - val_loss: 0.5626 - val_accuracy: 0.8014
# Epoch 85/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5569 - accuracy: 0.8019 - val_loss: 0.5628 - val_accuracy: 0.8009
# Epoch 86/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5562 - accuracy: 0.8021 - val_loss: 0.5629 - val_accuracy: 0.8010
# Epoch 87/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5568 - accuracy: 0.8020 - val_loss: 0.5620 - val_accuracy: 0.8012
# Epoch 88/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5585 - accuracy: 0.8014 - val_loss: 0.5633 - val_accuracy: 0.7987
# Epoch 89/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5554 - accuracy: 0.8015 - val_loss: 0.5592 - val_accuracy: 0.8018
# Epoch 90/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5536 - accuracy: 0.8019 - val_loss: 0.5573 - val_accuracy: 0.8008
# Epoch 91/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5537 - accuracy: 0.8020 - val_loss: 0.5594 - val_accuracy: 0.8011
# Epoch 92/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5537 - accuracy: 0.8021 - val_loss: 0.5591 - val_accuracy: 0.8004
# Epoch 93/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5533 - accuracy: 0.8021 - val_loss: 0.5577 - val_accuracy: 0.8010
# Epoch 94/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5722 - accuracy: 0.8023 - val_loss: 0.5588 - val_accuracy: 0.8015
# Epoch 95/1000
# 2884/2884 [==============================] - 74s 26ms/step - loss: 0.5516 - accuracy: 0.8024 - val_loss: 0.5591 - val_accuracy: 0.8007
# Epoch 96/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5502 - accuracy: 0.8026 - val_loss: 0.5569 - val_accuracy: 0.8014
# Epoch 97/1000
# 2884/2884 [==============================] - 75s 26ms/step - loss: 0.5498 - accuracy: 0.8027 - val_loss: 0.5596 - val_accuracy: 0.8008
# Epoch 98/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5494 - accuracy: 0.8027 - val_loss: 0.5561 - val_accuracy: 0.8010
# Epoch 99/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5491 - accuracy: 0.8030 - val_loss: 0.5566 - val_accuracy: 0.8010
# Epoch 100/1000
# 2884/2884 [==============================] - 79s 27ms/step - loss: 0.5485 - accuracy: 0.8029 - val_loss: 0.5558 - val_accuracy: 0.8014
# Epoch 101/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5483 - accuracy: 0.8032 - val_loss: 0.5573 - val_accuracy: 0.8012
# Epoch 102/1000
# 2884/2884 [==============================] - 79s 28ms/step - loss: 0.5480 - accuracy: 0.8031 - val_loss: 0.5581 - val_accuracy: 0.8006
# Epoch 103/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5472 - accuracy: 0.8033 - val_loss: 0.5575 - val_accuracy: 0.8008
# Epoch 104/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5476 - accuracy: 0.8035 - val_loss: 0.5576 - val_accuracy: 0.8006
# Epoch 105/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5472 - accuracy: 0.8035 - val_loss: 0.5605 - val_accuracy: 0.8006
# Epoch 106/1000
# 2884/2884 [==============================] - 78s 27ms/step - loss: 0.5507 - accuracy: 0.8032 - val_loss: 0.5569 - val_accuracy: 0.8010
# Epoch 107/1000
# 2884/2884 [==============================] - 77s 27ms/step - loss: 0.5500 - accuracy: 0.8033 - val_loss: 0.5578 - val_accuracy: 0.8013
# Epoch 108/1000
# 2884/2884 [==============================] - 76s 26ms/step - loss: 0.5486 - accuracy: 0.8035 - val_loss: 0.5598 - val_accuracy: 0.8006
# Epoch 109/1000
# 2884/2884 [==============================] - 73s 25ms/step - loss: 0.5475 - accuracy: 0.8037 - val_loss: 0.5578 - val_accuracy: 0.8014
# Epoch 110/1000
# 2884/2884 [==============================] - 71s 24ms/step - loss: 0.5474 - accuracy: 0.8038 - val_loss: 0.5566 - val_accuracy: 0.8010
# -----LSTM-------
# 902/902 [==============================] - 3s 3ms/step
# ACCURACY:  0.8009914607355321
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88    666582
#            1       0.85      0.64      0.73    131364
#            2       0.29      0.01      0.02     28806
#            3       0.48      0.03      0.06     95927
#
#     accuracy                           0.80    922679
#    macro avg       0.61      0.42      0.42    922679
# weighted avg       0.76      0.80      0.75    922679

# %%
plt.plot(lstm_hist.history['loss'], label = 'Loss')
plt.plot(lstm_hist.history['val_loss'], label = 'Validation Loss')
plt.title('LSTM Loss and Validation Loss Curves')

plt.legend(loc = 'best')
plt.show()

# %%
## XGBOOST

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
xgb_preds = xgb.predict(X_test)

print("-------XGBOOST-------")
print("ACCURACY: ", accuracy_score(y_test, xgb_preds))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, xgb_preds))
# Out:
# -------XGBOOST-------
# ACCURACY:  0.8595830876742734
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91    666298
#            1       0.91      0.78      0.84    131483
#            2       0.65      0.07      0.12     28957
#            3       0.77      0.46      0.58     95950
#
#     accuracy                           0.86    922688
#    macro avg       0.80      0.57      0.61    922688
# weighted avg       0.85      0.86      0.84    922688

# %%
## DECISION TREE

dt = DecisionTreeClassifier(max_depth = 4)
dt.fit(X_train, y_train)
dt_preds = dt.predict(X_test)

print("-------DECISION TREE--------")
print("ACCURACY: ", accuracy_score(y_test, dt_preds))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, dt_preds))
# Out:
# -------DECISION TREE--------
# ACCURACY:  0.7953479399320247
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88    666589
#            1       1.00      0.51      0.68    131364
#            2       0.00      0.00      0.00     28806
#            3       0.00      0.00      0.00     95929
#
#     accuracy                           0.80    922688
#    macro avg       0.44      0.38      0.39    922688
# weighted avg       0.71      0.80      0.73    922688
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## RANDOM FOREST

rf = RandomForestClassifier(n_estimators=100, max_depth=4)
rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)

print("-------RANDOM FOREST-------")
print("ACCURACY: ", accuracy_score(y_test, rf_preds))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, rf_preds))
# Out:
# -------RANDOM FOREST-------
# ACCURACY:  0.7953479399320247
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88    666589
#            1       1.00      0.51      0.68    131364
#            2       0.00      0.00      0.00     28806
#            3       0.00      0.00      0.00     95929
#
#     accuracy                           0.80    922688
#    macro avg       0.44      0.38      0.39    922688
# weighted avg       0.71      0.80      0.73    922688
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
