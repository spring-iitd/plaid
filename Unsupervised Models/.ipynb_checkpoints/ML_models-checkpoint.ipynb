# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.cluster import DBSCAN, KMeans
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score, average_precision_score
# import xgboost as xgb

# %%
data_dir = '../car_hacking_data/'
os.listdir(data_dir)
# Out:
# ['Fuzzy_dataset.csv',
#  'normal_run_data.txt',
#  'gear_dataset.csv',
#  '.DS_Store',
#  'RPM_dataset.csv',
#  'DoS_dataset.csv']

# %%
benign_data_path = os.path.join(data_dir, "normal_run_data.txt")
dos_data_path = os.path.join(data_dir, 'DoS_dataset.csv')

# %%
hex_to_dec = lambda x: int(x, 16)

## Since there are varying DLCs (2,5,6,8) in order to maintain data integrity
## The data must be padded with 00s when DLC < 8

def shift_columns(df):
    
    for dlc in [2,5,6]:

        df.loc[df['dlc'] == dlc, df.columns[3:]] = df.loc[df['dlc'] == dlc, df.columns[3:]].shift(periods=8-dlc, axis='columns', fill_value='00')

    return df

# %%
def read_attack_data(data_path):
    
    columns = ['timestamp','can_id', 'dlc', 'data0', 'data1', 'data2', 'data3', 'data4', 
           'data5', 'data6', 'data7', 'flag']
    
    data = pd.read_csv(data_path, names = columns)

    data = shift_columns(data)
    
    ##Replacing all NaNs with '00' 
    data = data.replace(np.NaN, '00')
    
    ##Joining all data columns to put all data in one column
    data_cols = ['data0', 'data1', 'data2', 'data3', 'data4', 'data5', 'data6', 'data7']
    
    ##The data column is in hexadecimal
    data['data'] = data[data_cols].apply(''.join, axis=1)
    data.drop(columns = data_cols, inplace = True, axis = 1)
    
    ##Converting columns to decimal
    data['can_id'] = data['can_id'].apply(hex_to_dec)
    data['data'] = data['data'].apply(hex_to_dec)
    
    data = data.assign(IAT=data['timestamp'].diff().fillna(0))
    
    return data

# %%
timestamps = []
ids = []
dlcs = []
data = []

# Read the data from the file
with open(benign_data_path, 'r') as file:
    for line in file:
        # Extract information from each line
        line = line.strip()
        ts = line.split('Timestamp: ')[1].split(' ')[0]
        can_id = line.split('ID: ')[1].split(' ')[0]
        dlc = line.split('DLC: ')[1].split(' ')[0]
        can_data = ''.join(line.split('DLC: ')[1].split(' ')[1:])
        
        #Converting Hexadecimal entries to decimal format
        timestamps.append(float(ts))
        ids.append(hex_to_dec(can_id))
        dlcs.append(int(dlc))
        data.append(hex_to_dec(can_data))
        
benign_data = pd.DataFrame({
    'timestamp': timestamps,
    'can_id': ids,
    'dlc': dlcs,
    'data': data
})

benign_data.sort_values(by = ['timestamp'], inplace = True)

# Creating IAT column
benign_data= benign_data.assign(IAT=benign_data['timestamp'].diff().fillna(0))
benign_data.drop(columns = ['timestamp'], axis = 1, inplace= True)

# %%
X = benign_data[['can_id', 'dlc', 'data', 'IAT']].values
y = np.zeros(benign_data.shape[0])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
dos_data = read_attack_data(dos_data_path)

# %%
dos_data = dos_data[dos_data['flag'] == 'T'][:100]

X_test = dos_data[['can_id', 'dlc', 'data', 'IAT']].values
y_test = dos_data['flag'].replace({'T' : 1}).values

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
def mse(inp, reconstructions):

    return np.mean(np.square(inp, reconstructions), axis = 1)

def generate_predictions(inp, reconstruction, threshold):

    reconstruction_error = mse(inp, reconstruction)
    preds = reconstruction_error > threshold

    return preds

# %%
print("XGBOOOST")

xgb_param_grid = {
        'max_depth' : [5, 7],
        'booster' : ['gbtree', 'gblinear'],
        'eta' : [0.3],
        'eval_metric' : ['rmse'],
        'n_estimators' : [100, 200],
        'subsample' : [0.8]}


xgb_model = xgb.XGBRegressor()


print("Grid Searching for best model!")
xgb_gs = GridSearchCV(xgb_model, param_grid=xgb_param_grid, cv = 10, scoring = 'neg_mean_squared_error', verbose = 2)
xgb_gs.fit(X_train, X_train)

print("Best Parameters:",xgb_gs.best_params_)
# Out:
# XGBOOOST
# Grid Searching for best model!
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  17.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  17.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  17.7s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  17.9s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  18.1s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  18.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  18.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  18.7s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  19.2s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=  18.9s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  34.4s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  35.0s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  37.1s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  37.2s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  38.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  36.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  38.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  39.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  38.7s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=  38.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  22.4s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  22.2s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  21.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  23.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  22.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  23.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  23.0s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  23.4s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  22.1s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=  21.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  37.9s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  37.4s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  36.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  40.3s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time= 2.2min
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  35.1s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  35.6s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  36.8s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  36.9s
# [CV] END booster=gbtree, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=  39.4s
# [20:41:10] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.5s
# [20:41:13] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.1s
# [20:41:16] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.3s
# [20:41:19] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.3s
# [20:41:23] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.3s
# [20:41:26] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.9s
# [20:41:30] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   4.0s
# [20:41:34] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.7s
# [20:41:38] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.5s
# [20:41:41] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=100, subsample=0.8; total time=   3.6s
# [20:41:45] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.1s
# [20:41:52] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.9s
# [20:42:00] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.5s
# [20:42:07] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.4s
# [20:42:15] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.7s
# [20:42:22] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.4s
# [20:42:30] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.2s
# [20:42:37] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.0s
# [20:42:44] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.3s
# [20:42:51] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=5, n_estimators=200, subsample=0.8; total time=   7.0s
# [20:42:58] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:01] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.5s
# [20:43:05] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:08] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:12] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:15] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:19] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.5s
# [20:43:22] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:25] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:29] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.4s
# [20:43:32] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.7s
# [20:43:39] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.7s
# [20:43:46] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   7.8s
# [20:43:53] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.7s
# [20:44:00] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   7.6s
# [20:44:08] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   7.4s
# [20:44:15] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.9s
# [20:44:22] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.8s
# [20:44:29] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.8s
# [20:44:36] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.3, eval_metric=rmse, max_depth=7, n_estimators=200, subsample=0.8; total time=   6.8s
# [20:44:42] WARNING: /var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_21wtzqx5vy/croot/xgboost-split_1675457780668/work/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# Best Parameters: {'booster': 'gblinear', 'eta': 0.3, 'eval_metric': 'rmse', 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}

# %%
xgb_best = xgb_gs.best_estimator_

train_reconstructions = xgb_best.predict(X_train)
train_reconstruction_error = mse(X_train, train_reconstructions)

val_reconstructions = xgb_best.predict(X_val)

test_reconstructions = xgb_best.predict(X_test)

thresholds_to_test = np.arange(0.1, 1.0, 0.05)

for thresholds in thresholds_to_test:
    
    threshold = np.quantile(train_reconstruction_error, thresholds)
    
    print("Currently testing threshold:", thresholds)

    val_preds = generate_predictions(X_val, val_reconstructions, threshold)
    print("Validation Accuracy:", accuracy_score(y_val, val_preds))

    test_preds = generate_predictions(X_test, test_reconstructions, threshold)
    print("Testing Accuracy Score:", accuracy_score(y_test, test_preds))

    print()
# Out:
# Currently testing threshold: 0.1
# Validation Accuracy: 0.10083175325496145
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.15000000000000002
# Validation Accuracy: 0.15079762356212867
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.20000000000000004
# Validation Accuracy: 0.20080394387561623
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.25000000000000006
# Validation Accuracy: 0.2517001643281507
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.30000000000000004
# Validation Accuracy: 0.30105422828972317
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.3500000000000001
# Validation Accuracy: 0.35133864239666285
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.40000000000000013
# Validation Accuracy: 0.40275565668057134
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.4500000000000001
# Validation Accuracy: 0.4523271394261155
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.5000000000000001
# Validation Accuracy: 0.5036834787005435
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.5500000000000002
# Validation Accuracy: 0.5527088863607635
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.6000000000000002
# Validation Accuracy: 0.6023916066236885
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.6500000000000001
# Validation Accuracy: 0.6518012893439514
# Testing Accuracy Score: 1.0
#
# Currently testing threshold: 0.7000000000000002
# Validation Accuracy: 0.7014435596005562
# Testing Accuracy Score: 0.02
#
# Currently testing threshold: 0.7500000000000002
# Validation Accuracy: 0.7512526861332323
# Testing Accuracy Score: 0.02
#
# Currently testing threshold: 0.8000000000000003
# Validation Accuracy: 0.8012741751990898
# Testing Accuracy Score: 0.02
#
# Currently testing threshold: 0.8500000000000003
# Validation Accuracy: 0.8513007205157376
# Testing Accuracy Score: 0.02
#
# Currently testing threshold: 0.9000000000000002
# Validation Accuracy: 0.901291872076855
# Testing Accuracy Score: 0.01
#
# Currently testing threshold: 0.9500000000000003
# Validation Accuracy: 0.9511465048666414
# Testing Accuracy Score: 0.01

# %%
print("SVM")

svm = OneClassSVM(kernel = 'rbf')

svm.fit(X_train)

preds = svm.predict(X_test)

print("Accuracy:", accuracy_score(y_test, preds))
# Out:
# SVM
