# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Dense, LSTM, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils import class_weight
from imblearn.over_sampling import SMOTE
import argparse
from joblib import dump
import matplotlib.pyplot as plt
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import eli5
from eli5.sklearn import PermutationImportance
# Out:
# 2024-02-21 14:16:46.269138: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
base_dir = '../data/Car Hacking Dataset/exp_factor_0.095/'

# %%
file_name = 'smart_output.csv'
data = pd.read_csv(os.path.join(base_dir, file_name))

data = data.assign(IAT=data['Timestamp'].diff().fillna(0))
data.drop(['Timestamp'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#        ID  DLC       Payload  label       IAT
# 0   848.0  8.0  3.716925e+17    0.0  0.000000
# 1   704.0  8.0  1.441152e+18    0.0  0.000221
# 2  1072.0  8.0  0.000000e+00    0.0  0.000554
# 3  1201.0  8.0  0.000000e+00    0.0  0.000238
# 4   497.0  8.0  0.000000e+00    0.0  0.000248

# %%
def hex_to_bin(hex_num):
    
    binary_value = bin(int(str(hex_num), 16))[2:]
    
    return binary_value

def int_to_bin(int_num):
    
    binary_value = bin(int_num)[2:]
    
    return binary_value

def pad(value, length):
    
    curr_length = len(str(value))
    
    zeros = '0' * (length - curr_length)
    
    return zeros + value

hex_to_dec = lambda x: int(x, 16)

def transform_data(data):

    data['ID'] = data['ID'].apply(hex_to_dec)
    data['Payload'] = data['Payload'].apply(hex_to_dec)

    return data

def sequencify_data(X, y, seq_size=10):
    max_index = len(X) - seq_size + 1

    X_seq = []
    y_seq = []

    for i in range(0, max_index, seq_size):
        X_seq.append(X[i:i+seq_size])  # Append the sequence from DataFrame 'X'
        y_seq.append(1 if 1 in y[i:i+seq_size] else 0)  # Check for '1' in 'y' values

    return np.array(X_seq), np.array(y_seq)

# data = transform_data(data)

# %%
X = data.drop('label', axis = 1)
y = data['label']

X_seq, y_seq = sequencify_data(X.values, y.values)

#Splitting into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)
X_seq_train, X_seq_test, y_seq_train, y_seq_test = train_test_split(X_seq, y_seq, test_size = 0.2, shuffle= True)

#Standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

seq_scaler = StandardScaler()
num_train_samples, seq_length, num_features = X_seq_train.shape
num_test_samples, _, _ = X_seq_test.shape

X_train_seq_reshaped = X_seq_train.reshape(num_train_samples, -1)
X_test_seq_reshaped = X_seq_test.reshape(num_test_samples, -1)

X_train_seq_scaled = seq_scaler.fit_transform(X_train_seq_reshaped)
X_test_seq_scaled = seq_scaler.transform(X_test_seq_reshaped)

# Reshape the scaled data back to the original shape
X_seq_train = X_train_seq_scaled.reshape(num_train_samples, seq_length, num_features)
X_seq_test = X_test_seq_scaled.reshape(num_test_samples, seq_length, num_features)

oversample = SMOTE()
X_train_smote, y_train_smote = oversample.fit_resample(X_train, y_train)

# %%
indexes = np.where(y_test == 1)[0]
X_test_attack = X_test[indexes]
y_test_attack = y_test.iloc[indexes]

# %%
def build_mlp():
    mlp = Sequential()
    mlp.add(Input(shape = (4)))
    mlp.add(Dense(128, activation = 'relu'))
    mlp.add(Dense(128, activation = 'relu'))
    mlp.add(Dense(1, activation = 'sigmoid'))

    mlp.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=['accuracy'])
    
    return mlp


es = EarlyStopping(monitor = 'val_loss', patience = 15, restore_best_weights = True)

mlp = KerasClassifier(build_fn = build_mlp, epochs = 100, batch_size = 128, validation_split = 0.2, callbacks = [es])
mlp.fit(X_train_smote, y_train_smote)
# Out:
# 2024-02-21 14:17:28.954601: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-02-21 14:17:28.989791: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-02-21 14:17:29.171453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:84:00.0 name: Tesla K40m computeCapability: 3.5
# coreClock: 0.745GHz coreCount: 15 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 268.58GiB/s
# 2024-02-21 14:17:29.171556: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-02-21 14:17:32.756634: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-02-21 14:17:32.756756: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-02-21 14:17:33.732170: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-02-21 14:17:34.243539: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-02-21 14:17:35.324745: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-02-21 14:17:35.701549: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-02-21 14:17:37.246577: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-02-21 14:17:37.248476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-02-21 14:17:37.323029: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 14:17:37.349283: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-02-21 14:17:37.402180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:84:00.0 name: Tesla K40m computeCapability: 3.5
# coreClock: 0.745GHz coreCount: 15 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 268.58GiB/s
# 2024-02-21 14:17:37.402252: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-02-21 14:17:37.402290: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-02-21 14:17:37.402324: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-02-21 14:17:37.402354: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-02-21 14:17:37.402384: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-02-21 14:17:37.402415: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-02-21 14:17:37.402445: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-02-21 14:17:37.402476: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-02-21 14:17:37.404097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-02-21 14:17:37.452171: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-02-21 14:17:45.929405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-02-21 14:17:45.929479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-02-21 14:17:45.929512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-02-21 14:17:45.964425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10611 MB memory) -> physical GPU (device: 0, name: Tesla K40m, pci bus id: 0000:84:00.0, compute capability: 3.5)
# 2024-02-21 14:17:47.480962: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-02-21 14:17:47.593756: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2497120000 Hz
# Epoch 1/100
# 2024-02-21 14:17:48.779463: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 9889/9889 [==============================] - 27s 2ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 5.9461e-05 - val_accuracy: 1.0000
# Epoch 2/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 1.1697e-04 - val_accuracy: 1.0000
# Epoch 3/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 1.5686e-04 - val_accuracy: 1.0000
# Epoch 4/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 4.4505e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 6.7362e-05 - val_accuracy: 1.0000
# Epoch 6/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 9.0568e-05 - val_accuracy: 1.0000
# Epoch 7/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 9.0633e-04 - accuracy: 0.9999 - val_loss: 1.1853e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 9.1053e-04 - accuracy: 0.9999 - val_loss: 9.1764e-05 - val_accuracy: 1.0000
# Epoch 9/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 8.8161e-04 - accuracy: 0.9999 - val_loss: 8.3342e-04 - val_accuracy: 1.0000
# Epoch 10/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.8424e-04 - accuracy: 0.9999 - val_loss: 5.9237e-05 - val_accuracy: 1.0000
# Epoch 11/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 8.1063e-04 - accuracy: 0.9999 - val_loss: 4.8869e-05 - val_accuracy: 1.0000
# Epoch 12/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.9406e-04 - accuracy: 0.9999 - val_loss: 5.1036e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.5901e-04 - accuracy: 0.9999 - val_loss: 2.2713e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.5590e-04 - accuracy: 0.9999 - val_loss: 1.2526e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.8888e-04 - accuracy: 0.9999 - val_loss: 2.9572e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.1278e-04 - accuracy: 0.9999 - val_loss: 8.5976e-05 - val_accuracy: 1.0000
# Epoch 17/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.8945e-04 - accuracy: 0.9999 - val_loss: 3.6442e-05 - val_accuracy: 1.0000
# Epoch 18/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.8085e-04 - accuracy: 0.9999 - val_loss: 1.2830e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.0595e-04 - accuracy: 0.9999 - val_loss: 5.9257e-05 - val_accuracy: 1.0000
# Epoch 20/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.4756e-04 - accuracy: 0.9999 - val_loss: 1.1537e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.0791e-04 - accuracy: 0.9999 - val_loss: 1.1943e-04 - val_accuracy: 1.0000
# Epoch 22/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.9516e-04 - accuracy: 0.9999 - val_loss: 1.3605e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.6050e-04 - accuracy: 0.9999 - val_loss: 7.9264e-05 - val_accuracy: 1.0000
# Epoch 24/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.3382e-04 - accuracy: 0.9999 - val_loss: 3.1277e-05 - val_accuracy: 1.0000
# Epoch 25/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 7.2395e-04 - accuracy: 0.9999 - val_loss: 6.5584e-05 - val_accuracy: 1.0000
# Epoch 26/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.8807e-04 - accuracy: 0.9999 - val_loss: 1.9773e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.9690e-04 - accuracy: 0.9999 - val_loss: 9.3712e-05 - val_accuracy: 1.0000
# Epoch 28/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.1463e-04 - accuracy: 0.9999 - val_loss: 1.3235e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.6341e-04 - accuracy: 0.9999 - val_loss: 3.4830e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.2230e-04 - accuracy: 0.9999 - val_loss: 4.2597e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.7685e-04 - accuracy: 0.9999 - val_loss: 9.0979e-05 - val_accuracy: 1.0000
# Epoch 32/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.0786e-04 - accuracy: 0.9999 - val_loss: 5.5924e-05 - val_accuracy: 1.0000
# Epoch 33/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.2740e-04 - accuracy: 0.9999 - val_loss: 1.5919e-05 - val_accuracy: 1.0000
# Epoch 34/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.3506e-04 - accuracy: 0.9999 - val_loss: 4.7131e-05 - val_accuracy: 1.0000
# Epoch 35/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.3869e-04 - accuracy: 0.9999 - val_loss: 2.3697e-05 - val_accuracy: 1.0000
# Epoch 36/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.5060e-04 - accuracy: 0.9999 - val_loss: 3.1455e-05 - val_accuracy: 1.0000
# Epoch 37/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.3796e-04 - accuracy: 0.9999 - val_loss: 4.0130e-05 - val_accuracy: 1.0000
# Epoch 38/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.9516e-04 - accuracy: 0.9999 - val_loss: 1.1892e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.1768e-04 - accuracy: 0.9999 - val_loss: 2.9354e-05 - val_accuracy: 1.0000
# Epoch 40/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.1929e-04 - accuracy: 0.9999 - val_loss: 1.9437e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 6.0821e-04 - accuracy: 0.9999 - val_loss: 9.8601e-05 - val_accuracy: 1.0000
# Epoch 42/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.5864e-04 - accuracy: 0.9999 - val_loss: 3.9998e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 4.6828e-04 - accuracy: 0.9999 - val_loss: 1.3704e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.1925e-04 - accuracy: 0.9999 - val_loss: 6.9938e-05 - val_accuracy: 1.0000
# Epoch 45/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.0172e-04 - accuracy: 0.9999 - val_loss: 8.9528e-05 - val_accuracy: 1.0000
# Epoch 46/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 4.0149e-04 - accuracy: 0.9999 - val_loss: 8.3667e-05 - val_accuracy: 1.0000
# Epoch 47/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 4.9705e-04 - accuracy: 0.9999 - val_loss: 3.8252e-05 - val_accuracy: 1.0000
# Epoch 48/100
# 9889/9889 [==============================] - 16s 2ms/step - loss: 5.7782e-04 - accuracy: 0.9999 - val_loss: 1.5938e-05 - val_accuracy: 1.0000

# %%
perm_mlp = PermutationImportance(mlp, random_state=1).fit(X_test, y_test)
eli5.show_weights(perm_mlp, feature_names = X.columns.tolist())
# Out:
# 1552/1552 [==============================] - 2s 1ms/step - loss: 9.6985e-04 - accuracy: 0.9998
# 1552/1552 [==============================] - 2s 1ms/step - loss: 0.3882 - accuracy: 0.9934
# 1552/1552 [==============================] - 2s 1ms/step - loss: 0.2086 - accuracy: 0.9989
# 1552/1552 [==============================] - 2s 990us/step - loss: 0.1308 - accuracy: 0.9978
# 1552/1552 [==============================] - 2s 1ms/step - loss: 0.4987 - accuracy: 0.9957
# 1552/1552 [==============================] - 2s 1ms/step - loss: 0.4007 - accuracy: 0.9933
# 1552/1552 [==============================] - 2s 999us/step - loss: 0.1801 - accuracy: 0.9989
# 1211/1552 [======================>.......] - ETA: 0s - loss: 0.1238 - accuracy: 0.9979

# %%
xgb = XGBClassifier()
xgb.fit(X_train_smote, y_train_smote)

perm_xgb = PermutationImportance(xgb, random_state = 1).fit(X_test_attack, y_test_attack)
eli5.show_weights(perm_xgb, feature_names = X.columns.tolist())
# Out:
# /home/cse/visitor/anwesh.visitor/.conda/envs/tf/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:29:06] WARNING: /croot/xgboost-split_1675119646044/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1510
#
#                     &plusmn; 0.0145
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IAT
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1445
#
#                     &plusmn; 0.0130
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payload
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DLC
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
dt = DecisionTreeClassifier(max_depth = 3)
dt.fit(X_train_smote, y_train_smote)

perm_dt = PermutationImportance(dt, random_state = 1).fit(X_test, y_test)
eli5.show_weights(perm_dt, feature_names = X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IAT
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0018
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DLC
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payload
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
rf = RandomForestClassifier(n_estimators = 100, max_depth = 2)
rf.fit(X_train_smote, y_train_smote)

perm_rf = PermutationImportance(rf, random_state = 1).fit(X_test, y_test)
eli5.show_weights(perm_rf, feature_names = X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0051
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IAT
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DLC
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payload
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0013
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>
