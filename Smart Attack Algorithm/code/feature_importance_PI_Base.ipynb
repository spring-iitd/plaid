# %%
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Dense, LSTM, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils import class_weight
from imblearn.over_sampling import SMOTE
import argparse
from joblib import dump
import matplotlib.pyplot as plt
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import eli5
from eli5.sklearn import PermutationImportance

# %%
base_dir = '../data/Car Hacking Dataset/'

# %%
file_name = 'preprocessed_car_hacking.csv'
data = pd.read_csv(os.path.join(base_dir, file_name))

data = data.assign(IAT=data['Timestamp'].diff().fillna(0))
data.drop(['Timestamp'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#      ID  DLC           Payload       IAT  label
# 0  0316    8  052168092121006f  0.000000      0
# 1  018f    8  fe5b0000003c0000  0.000209      0
# 2  0260    8  19212230088e6d3a  0.000228      0
# 3  02a0    8  64009a1d9702bd00  0.000232      0
# 4  0329    8  40bb7f1411200014  0.000237      0

# %%
def hex_to_bin(hex_num):
    
    binary_value = bin(int(str(hex_num), 16))[2:]
    
    return binary_value

def int_to_bin(int_num):
    
    binary_value = bin(int_num)[2:]
    
    return binary_value

def pad(value, length):
    
    curr_length = len(str(value))
    
    zeros = '0' * (length - curr_length)
    
    return zeros + value

hex_to_dec = lambda x: int(x, 16)

def transform_data(data):

    data['ID'] = data['ID'].apply(hex_to_dec)
    data['Payload'] = data['Payload'].apply(hex_to_dec)

    return data

def sequencify_data(X, y, seq_size=10):
    max_index = len(X) - seq_size + 1

    X_seq = []
    y_seq = []

    for i in range(0, max_index, seq_size):
        X_seq.append(X[i:i+seq_size])  # Append the sequence from DataFrame 'X'
        y_seq.append(1 if 1 in y[i:i+seq_size] else 0)  # Check for '1' in 'y' values

    return np.array(X_seq), np.array(y_seq)

data = transform_data(data)

data.head()
# Out:
#     ID  DLC               Payload       IAT  label
# 0  790    8    369691032840896623  0.000000      0
# 1  399    8  18328243108518297600  0.000209      0
# 2  608    8   1810766114876976442  0.000228      0
# 3  672    8   7205928855671061760  0.000232      0
# 4  809    8   4664461563235663892  0.000237      0

# %%
X = data.drop('label', axis = 1)
y = data['label']

X_seq, y_seq = sequencify_data(X.values, y.values)

#Splitting into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)
X_seq_train, X_seq_test, y_seq_train, y_seq_test = train_test_split(X_seq, y_seq, test_size = 0.2, shuffle= True)

#Standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

seq_scaler = StandardScaler()
num_train_samples, seq_length, num_features = X_seq_train.shape
num_test_samples, _, _ = X_seq_test.shape

X_train_seq_reshaped = X_seq_train.reshape(num_train_samples, -1)
X_test_seq_reshaped = X_seq_test.reshape(num_test_samples, -1)

X_train_seq_scaled = seq_scaler.fit_transform(X_train_seq_reshaped)
X_test_seq_scaled = seq_scaler.transform(X_test_seq_reshaped)

# Reshape the scaled data back to the original shape
X_seq_train = X_train_seq_scaled.reshape(num_train_samples, seq_length, num_features)
X_seq_test = X_test_seq_scaled.reshape(num_test_samples, seq_length, num_features)

oversample = SMOTE()
X_train_smote, y_train_smote = oversample.fit_resample(X_train, y_train)

# %%
indexes = np.where(y_test == 1)[0]
X_test_attack = X_test[indexes]
y_test_attack = y_test.iloc[indexes]

# %%
# def build_mlp():
#     mlp = Sequential()
#     mlp.add(Input(shape = (4)))
#     mlp.add(Dense(128, activation = 'relu'))
#     mlp.add(Dense(128, activation = 'relu'))
#     mlp.add(Dense(1, activation = 'sigmoid'))

#     mlp.compile(optimizer='adam',
#                     loss='binary_crossentropy',
#                     metrics=['accuracy'])
    
#     return mlp


# es = EarlyStopping(monitor = 'val_loss', patience = 15, restore_best_weights = True)

# mlp = KerasClassifier(build_fn = build_mlp, epochs = 100, batch_size = 128, validation_split = 0.2, callbacks = [es])
# mlp.fit(X_train_smote, y_train_smote)
# Out:
# 2024-02-22 14:00:13.616222: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-02-22 14:00:13.617913: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-02-22 14:00:13.641750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:86:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.74GiB deviceMemoryBandwidth: 836.37GiB/s
# 2024-02-22 14:00:13.641788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-02-22 14:00:16.877450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-02-22 14:00:16.877603: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-02-22 14:00:17.649474: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-02-22 14:00:17.981435: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-02-22 14:00:18.877418: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-02-22 14:00:19.200221: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-02-22 14:00:20.911443: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-02-22 14:00:20.912297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-02-22 14:00:20.977516: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-22 14:00:20.988996: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-02-22 14:00:21.021825: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:86:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.74GiB deviceMemoryBandwidth: 836.37GiB/s
# 2024-02-22 14:00:21.021866: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-02-22 14:00:21.021889: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-02-22 14:00:21.021906: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-02-22 14:00:21.021923: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-02-22 14:00:21.021938: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-02-22 14:00:21.021954: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-02-22 14:00:21.021970: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-02-22 14:00:21.021986: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-02-22 14:00:21.022442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-02-22 14:00:21.060853: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-02-22 14:00:25.968180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-02-22 14:00:25.968264: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-02-22 14:00:25.968304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-02-22 14:00:25.992520: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 29697 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:86:00.0, compute capability: 7.0)
# 2024-02-22 14:00:27.465032: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-02-22 14:00:27.573144: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2400000000 Hz
# Epoch 1/100
# 2024-02-22 14:00:28.834792: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 30788/30788 [==============================] - 68s 2ms/step - loss: 0.1094 - accuracy: 0.9678 - val_loss: 0.0627 - val_accuracy: 0.9958
# Epoch 2/100
# 30788/30788 [==============================] - 59s 2ms/step - loss: 0.0908 - accuracy: 0.9725 - val_loss: 0.0448 - val_accuracy: 0.9991
# Epoch 3/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0367 - accuracy: 0.9908 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 4/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0370 - accuracy: 0.9887 - val_loss: 0.0474 - val_accuracy: 0.9992
# Epoch 5/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0266 - accuracy: 0.9950 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 6/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0290 - accuracy: 0.9959 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 7/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0221 - accuracy: 0.9977 - val_loss: 0.0377 - val_accuracy: 0.9994
# Epoch 8/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0256 - accuracy: 0.9946 - val_loss: 0.0082 - val_accuracy: 0.9992
# Epoch 9/100
# 30788/30788 [==============================] - 60s 2ms/step - loss: 0.0285 - accuracy: 0.9934 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 10/100
# 30788/30788 [==============================] - 59s 2ms/step - loss: 0.0207 - accuracy: 0.9961 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 11/100
# 30788/30788 [==============================] - 59s 2ms/step - loss: 0.0164 - accuracy: 0.9977 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 12/100
# 30788/30788 [==============================] - 59s 2ms/step - loss: 0.0184 - accuracy: 0.9975 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 13/100
# 30788/30788 [==============================] - 59s 2ms/step - loss: 0.0148 - accuracy: 0.9986 - val_loss: 0.0376 - val_accuracy: 0.9996
# Epoch 14/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0173 - accuracy: 0.9971 - val_loss: 0.0165 - val_accuracy: 0.9999
# Epoch 15/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0130 - accuracy: 0.9990 - val_loss: 4.1122e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0148 - accuracy: 0.9988 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 17/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0202 - accuracy: 0.9980 - val_loss: 0.0082 - val_accuracy: 0.9999
# Epoch 18/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0105 - accuracy: 0.9993 - val_loss: 0.0043 - val_accuracy: 0.9992
# Epoch 19/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.1014 - accuracy: 0.9991 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 20/100
# 30788/30788 [==============================] - 47s 2ms/step - loss: 0.0083 - accuracy: 0.9993 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 21/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0080 - accuracy: 0.9992 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 22/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 23/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0119 - accuracy: 0.9977 - val_loss: 2.3679e-04 - val_accuracy: 1.0000
# Epoch 24/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0077 - accuracy: 0.9994 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 25/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 5.8828e-05 - val_accuracy: 1.0000
# Epoch 26/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0141 - accuracy: 0.9991 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 27/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 28/100
# 30788/30788 [==============================] - 53s 2ms/step - loss: 0.0149 - accuracy: 0.9989 - val_loss: 7.1765e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0084 - accuracy: 0.9995 - val_loss: 0.0187 - val_accuracy: 0.9996
# Epoch 30/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0130 - accuracy: 0.9992 - val_loss: 7.3522e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0097 - accuracy: 0.9992 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 32/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0059 - accuracy: 0.9996 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 33/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0104 - accuracy: 0.9992 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 34/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0073 - accuracy: 0.9993 - val_loss: 6.5034e-04 - val_accuracy: 1.0000
# Epoch 35/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0084 - accuracy: 0.9993 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 36/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0073 - accuracy: 0.9993 - val_loss: 0.0045 - val_accuracy: 0.9991
# Epoch 37/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 8.5681e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0099 - accuracy: 0.9993 - val_loss: 9.4450e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 30788/30788 [==============================] - 49s 2ms/step - loss: 0.0048 - accuracy: 0.9996 - val_loss: 5.6178e-04 - val_accuracy: 1.0000
# Epoch 40/100
# 30788/30788 [==============================] - 48s 2ms/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 7.1466e-04 - val_accuracy: 1.0000

# %%
# perm_mlp = PermutationImportance(mlp, random_state=1).fit(X_test_attack, y_test_attack)
# eli5.show_weights(perm_mlp, feature_names = X.columns.tolist())
# Out:
# 922/922 [==============================] - 1s 945us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 918us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 921us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 920us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 922us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 923us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 923us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 919us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 916us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 919us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 917us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 919us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 922us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 920us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 919us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 919us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 922us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 915us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 920us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 921us/step - loss: 0.0046 - accuracy: 1.0000
# 922/922 [==============================] - 1s 918us/step - loss: 0.0046 - accuracy: 1.0000
# /home/cse/visitor/anwesh.visitor/.conda/envs/tf/lib/python3.7/site-packages/eli5/formatters/html.py:237: RuntimeWarning: invalid value encountered in double_scalars
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(0, 100.00%, nan%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IAT
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, nan%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payload
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, nan%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DLC
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, nan%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
xgb = XGBClassifier()
xgb.fit(X_train_smote, y_train_smote)

perm_xgb = PermutationImportance(xgb, random_state = 1).fit(X_test, y_test)
eli5.show_weights(perm_xgb, feature_names = X.columns.tolist())

# %%
X_train_smote
# Out:
# array([[ 0.04215836,  0.09270541, -0.30081906, -0.36840644],
#        [-0.66333764,  0.09270541, -0.23989316,  0.20275524],
#        [ 1.15377871,  0.09270541, -0.57169923, -0.02776887],
#        ...,
#        [-1.36883364,  0.09270541, -0.57455211, -0.36292568],
#        [-1.36883364,  0.09270541, -0.57455211,  3.24972594],
#        [-1.36883364,  0.09270541, -0.57455211, -0.1900326 ]])

# %%
scaler.inverse_transform([[-1.,0,0,0]])
# Out:
# array([[-5.02588125e-01,  7.94887363e+00,  3.64946309e+18,
#          7.66801381e-04]])

# %%
dt = DecisionTreeClassifier(max_depth = 3)
dt.fit(X_train_smote, y_train_smote)

perm_dt = PermutationImportance(dt, random_state = 1).fit(X_test, y_test)
eli5.show_weights(perm_dt, feature_names = X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.5001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ID
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 IAT
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Payload
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DLC
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
rf = RandomForestClassifier(n_estimators = 100, max_depth = 2)
rf.fit(X_train_smote, y_train_smote)

perm_rf = PermutationImportance(rf, random_state = 1).fit(X_test, y_test)
eli5.show_weights(perm_rf, feature_names = X.columns.tolist())

# %%
X.columns
# Out:
# Index(['ID', 'DLC', 'Payload', 'IAT'], dtype='object')
