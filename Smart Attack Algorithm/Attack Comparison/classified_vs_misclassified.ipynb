# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_text, export_graphviz
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.utils import class_weight
import joblib
# Out:
# 2024-10-15 10:25:02.767303: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_folder = 'Car-Hacking/'
print(os.listdir(data_folder))
smart_attack_path = 'attack_10_10.csv'
# Out:
# ['Fuzzy_dataset.csv', 'normal_run_data.7z', 'normal_run_data', 'DoS_dataset.csv', 'RPM_dataset.csv', 'gear_dataset.csv']

# %%
def hex_to_bin(hex_num):
    
    binary_value = bin(int(str(hex_num), 16))[2:]
    
    return binary_value

def int_to_bin(int_num):
    
    binary_value = bin(int_num)[2:]
    
    return binary_value

def pad(value, length):
    
    curr_length = len(str(value))
    
    zeros = '0' * (length - curr_length)
    
    return zeros + value

hex_to_dec = lambda x: int(x, 16)

def transform_data(data):

    data['ID'] = data['ID'].apply(hex_to_dec)
    data['Payload'] = data['Payload'].apply(hex_to_dec)

    return data

# %%
smart_attack = pd.read_csv(smart_attack_path)

# %%
smart_attack.drop(columns = ['Timestamp'], inplace = True)

# %%
X_smart = smart_attack.drop(['label'], axis = 1).values
y_smart = smart_attack['label']
y_smart = y_smart.replace(2,1)

# %%
X_train_smart, X_test_smart, y_train_smart, y_test_smart = train_test_split(X_smart, y_smart, test_size=0.3, random_state = 42, shuffle = False)

# %%
scaler = StandardScaler()

X_train_smart = scaler.fit_transform(X_train_smart)
X_test_smart = scaler.transform(X_test_smart)

# %%
oversample = SMOTE()
X_train_smote, y_train_smote = oversample.fit_resample(X_train_smart, y_train_smart)

# %%
##MLP

print("-----MLP-------")

mlp = Sequential()
mlp.add(Input(shape = (4)))
mlp.add(Dense(128, activation = 'relu'))
mlp.add(Dense(64, activation = 'relu'))
mlp.add(Dense(1, activation = 'sigmoid'))

mlp.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])

es = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True)

mlp_hist = mlp.fit(X_train_smote, y_train_smote, epochs=100, callbacks = [es], validation_split=0.2, batch_size = 32)
# Out:
# -----MLP-------
# Epoch 1/100
# 2024-10-15 10:29:56.509524: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-15 10:29:56.514364: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.5819 - accuracy: 0.7020 - val_loss: 0.8240 - val_accuracy: 0.4020
# Epoch 2/100
# 3507/3507 [==============================] - 11s 3ms/step - loss: 0.5541 - accuracy: 0.7211 - val_loss: 0.7424 - val_accuracy: 0.4769
# Epoch 3/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.5313 - accuracy: 0.7392 - val_loss: 0.7321 - val_accuracy: 0.5202
# Epoch 4/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.5045 - accuracy: 0.7578 - val_loss: 0.6806 - val_accuracy: 0.5721
# Epoch 5/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.4823 - accuracy: 0.7722 - val_loss: 0.8249 - val_accuracy: 0.5389
# Epoch 6/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.4648 - accuracy: 0.7816 - val_loss: 0.6713 - val_accuracy: 0.6379
# Epoch 7/100
# 3507/3507 [==============================] - 11s 3ms/step - loss: 0.4523 - accuracy: 0.7881 - val_loss: 0.6594 - val_accuracy: 0.6325
# Epoch 8/100
# 3507/3507 [==============================] - 9s 3ms/step - loss: 0.4406 - accuracy: 0.7942 - val_loss: 0.5326 - val_accuracy: 0.7293
# Epoch 9/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.4342 - accuracy: 0.7971 - val_loss: 0.7043 - val_accuracy: 0.6325
# Epoch 10/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.4270 - accuracy: 0.8017 - val_loss: 0.6215 - val_accuracy: 0.6846
# Epoch 11/100
# 3507/3507 [==============================] - 9s 3ms/step - loss: 0.4242 - accuracy: 0.8027 - val_loss: 0.5903 - val_accuracy: 0.6832
# Epoch 12/100
# 3507/3507 [==============================] - 10s 3ms/step - loss: 0.4209 - accuracy: 0.8043 - val_loss: 0.5476 - val_accuracy: 0.7404
# Epoch 13/100
# 3507/3507 [==============================] - 9s 3ms/step - loss: 0.4175 - accuracy: 0.8067 - val_loss: 0.6007 - val_accuracy: 0.6827

# %%
##MLP
print("-----MLP-------")
threshold = 0.5
mlp_preds = mlp.predict(X_test_smart, batch_size = 32)
mlp_preds = (mlp_preds >= threshold).astype(int)

print("--------Smart--------")
print("ACCURACY: ", accuracy_score(y_test_smart, mlp_preds))
print("CLASSIFICATION REPORT:\n", classification_report(y_test_smart, mlp_preds))
# Out:
# -----MLP-------
# 1383/1383 [==============================] - 1s 989us/step
# --------Smart--------
# ACCURACY:  0.8089920658242727
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.84      0.86     29873
#          1.0       0.69      0.74      0.71     14366
#
#     accuracy                           0.81     44239
#    macro avg       0.78      0.79      0.79     44239
# weighted avg       0.81      0.81      0.81     44239

# %%
smart_attack = pd.read_csv(smart_attack_path)

smart_attack.drop(columns = ['Timestamp'], inplace = True)
X_smart = smart_attack.drop(['label'], axis = 1).values
y_smart = smart_attack['label']

X_train_smart, X_test_smart, y_train_smart, y_test_smart = train_test_split(X_smart, y_smart, test_size=0.3, random_state = 42)

# %%
test_scaled = scaler.transform(X_smart)
preds = mlp.predict(test_scaled)
preds = (preds >= threshold).astype(int)
# Out:
# 4609/4609 [==============================] - 4s 842us/step

# %%
X_test_results = pd.DataFrame(data = X_smart, columns = ['ID', 'DLC', 'Payload', "IAT"])

# %%
X_test_results['Packet Type'] = np.array(y_smart)
X_test_results['Prediction'] = np.array(preds)

# %%
X_test_results['Correctly Predicted'] = np.where(
    ((X_test_results['Packet Type'] == 0) & (X_test_results['Prediction'] == 0)) | 
    ((X_test_results['Packet Type'].isin([1, 2])) & (X_test_results['Prediction'] == 1)),
    1,  # Set to 1 when the conditions are met
    0   # Set to 0 in any other case
)

# %%
# X_test_results.to_csv('results.csv', index = False)

# %%
X_test_results['IAT'] = X_test_results['IAT'] * 1e6

# %%
X_test_results.head()
# Out:
#        ID  DLC       Payload         IAT  Packet Type  Prediction  \
# 0   848.0  8.0  3.716925e+17    0.000000          0.0           0
# 1   704.0  8.0  1.441152e+18  221.014023          0.0           1
# 2  1072.0  8.0  0.000000e+00  553.846359          0.0           1
# 3  1201.0  8.0  0.000000e+00  237.941742          0.0           0
# 4   497.0  8.0  0.000000e+00  248.193741          0.0           0
#
#    Correctly Predicted
# 0                    1
# 1                    0
# 2                    0
# 3                    1
# 4                    1

# %%
# Group by ID
grouped_by_id = X_test_results.groupby('ID')

for id_value, group in grouped_by_id:
    # Overall statistics for each ID
    overall_mean_iat = group['IAT'].mean()
    overall_median_iat = group['IAT'].median()

    print(f"ID: {id_value}")
    print(f"Overall Mean IAT: {overall_mean_iat}")
    print(f"Overall Median IAT: {overall_median_iat}")

    print()

    group = group[group['Packet Type'].isin([1, 2])]

    # Statistics for 'Correctly Predicted' = 1
    correctly_predicted_1 = group[group['Correctly Predicted'] == 1]
    mean_iat_correct_1 = correctly_predicted_1['IAT'].mean()
    median_iat_correct_1 = correctly_predicted_1['IAT'].median()

    # Statistics for 'Correctly Predicted' = 0
    correctly_predicted_0 = group[group['Correctly Predicted'] == 0]
    mean_iat_correct_0 = correctly_predicted_0['IAT'].mean()
    median_iat_correct_0 = correctly_predicted_0['IAT'].median()

    print(f"Mean IAT for Detected Packets: {mean_iat_correct_1}")
    print(f"Mean IAT for evaded packets: {mean_iat_correct_0}")
    
    print(f"Median IAT for Detected Packets: {median_iat_correct_1}")
    print(f"Median IAT for evaded packets: {median_iat_correct_0}")

    print("----------------------------")
# Out:
# ID: 2.0
# Overall Mean IAT: 317.95913703774886
# Overall Median IAT: 241.994857788
#
# Mean IAT for Detected Packets: 422.98318035600875
# Mean IAT for evaded packets: 252.58353922892636
# Median IAT for Detected Packets: 236.0343933105
# Median IAT for evaded packets: 246.04797363279997
# ----------------------------
# ID: 160.0
# Overall Mean IAT: 439.4342400144029
# Overall Median IAT: 240.0875091552
#
# Mean IAT for Detected Packets: 502.5030101785419
# Mean IAT for evaded packets: 252.38175141180128
# Median IAT for Detected Packets: 246.04797363279997
# Median IAT for evaded packets: 230.073928833
# ----------------------------
# ID: 161.0
# Overall Mean IAT: 235.30015520224566
# Overall Median IAT: 236.0343933105
#
# Mean IAT for Detected Packets: 236.4392938284586
# Mean IAT for evaded packets: nan
# Median IAT for Detected Packets: 236.0343933105
# Median IAT for evaded packets: nan
# ----------------------------
# ID: 304.0
# Overall Mean IAT: 262.00338972469257
# Overall Median IAT: 237.94174194329997
#
# Mean IAT for Detected Packets: 269.1452835474249
# Mean IAT for evaded packets: 240.44282769227874
# Median IAT for Detected Packets: 247.95532226560002
# Median IAT for evaded packets: 236.0343933105
# ----------------------------
# ID: 305.0
# Overall Mean IAT: 233.77671313097417
# Overall Median IAT: 233.88862609859999
#
# Mean IAT for Detected Packets: 235.65261192566666
# Mean IAT for evaded packets: 234.76931104343365
# Median IAT for Detected Packets: 236.0343933105
# Median IAT for evaded packets: 233.88862609859999
# ----------------------------
# ID: 320.0
# Overall Mean IAT: 244.62362654554562
# Overall Median IAT: 240.80276489250002
#
# Mean IAT for Detected Packets: 235.66770207213602
# Mean IAT for evaded packets: 240.71215570851118
# Median IAT for Detected Packets: 236.0343933105
# Median IAT for evaded packets: 240.0875091552
# ----------------------------
# ID: 339.0
# Overall Mean IAT: 307.2115091176628
# Overall Median IAT: 243.90220642079998
#
# Mean IAT for Detected Packets: 1651.1077955951341
# Mean IAT for evaded packets: 269.121681617548
# Median IAT for Detected Packets: 1685.02330780025
# Median IAT for evaded packets: 246.04797363279997
# ----------------------------
# ID: 399.0
# Overall Mean IAT: 238.22966377751908
# Overall Median IAT: 230.073928833
#
# Mean IAT for Detected Packets: 619.5974873972001
# Mean IAT for evaded packets: 245.48267862594182
# Median IAT for Detected Packets: 311.13624572749995
# Median IAT for evaded packets: 237.94174194329997
# ----------------------------
# ID: 497.0
# Overall Mean IAT: 247.95355620202773
# Overall Median IAT: 241.994857788
#
# Mean IAT for Detected Packets: nan
# Mean IAT for evaded packets: 239.43185806269997
# Median IAT for Detected Packets: nan
# Median IAT for evaded packets: 237.94174194329997
# ----------------------------
# ID: 608.0
# Overall Mean IAT: 231.78359006167588
# Overall Median IAT: 231.0276031494
#
# Mean IAT for Detected Packets: 238.85727551410451
# Mean IAT for evaded packets: nan
# Median IAT for Detected Packets: 237.94174194329997
# Median IAT for evaded packets: nan
# ----------------------------
# ID: 672.0
# Overall Mean IAT: 242.37583816495996
# Overall Median IAT: 238.8954162597
#
# Mean IAT for Detected Packets: 230.98611340076778
# Mean IAT for evaded packets: 240.92765081488912
# Median IAT for Detected Packets: 230.073928833
# Median IAT for evaded packets: 241.994857788
# ----------------------------
# ID: 688.0
# Overall Mean IAT: 356.6529926355119
# Overall Median IAT: 186.92016601560002
#
# Mean IAT for Detected Packets: 588.8838292387212
# Mean IAT for evaded packets: 177.38783801038335
# Median IAT for Detected Packets: 277.40001678465
# Median IAT for evaded packets: 174.99923706049998
# ----------------------------
# ID: 704.0
# Overall Mean IAT: 683.6802006532783
# Overall Median IAT: 247.95532226560002
#
# Mean IAT for Detected Packets: 1298.0868365313058
# Mean IAT for evaded packets: 242.65900308693625
# Median IAT for Detected Packets: 1154.1843414306002
# Median IAT for evaded packets: 241.994857788
# ----------------------------
# ID: 790.0
# Overall Mean IAT: 578.912403762188
# Overall Median IAT: 236.0343933105
#
# Mean IAT for Detected Packets: 1177.8552362021862
# Mean IAT for evaded packets: 248.5413908432775
# Median IAT for Detected Packets: 705.5997848510501
# Median IAT for evaded packets: 237.94174194329997
# ----------------------------
# ID: 809.0
# Overall Mean IAT: 233.75938769763061
# Overall Median IAT: 233.1733703613
#
# Mean IAT for Detected Packets: 229.17189812571436
# Mean IAT for evaded packets: 234.6642269110382
# Median IAT for Detected Packets: 237.94174194329997
# Median IAT for evaded packets: 236.0343933105
# ----------------------------
# ID: 848.0
# Overall Mean IAT: 445.5263253413845
# Overall Median IAT: 236.0343933105
#
# Mean IAT for Detected Packets: 796.3321413615895
# Mean IAT for evaded packets: 229.25149410139107
# Median IAT for Detected Packets: 378.131866455
# Median IAT for evaded packets: 231.98127746580002
# ----------------------------
# ID: 880.0
# Overall Mean IAT: 247.39753955404797
# Overall Median IAT: 233.88862609859999
#
# Mean IAT for Detected Packets: 462.58600650984164
# Mean IAT for evaded packets: 235.45131963838836
# Median IAT for Detected Packets: 241.994857788
# Median IAT for evaded packets: 233.88862609859999
# ----------------------------
# ID: 1072.0
# Overall Mean IAT: 374.0876342834473
# Overall Median IAT: 250.10108947749998
#
# Mean IAT for Detected Packets: 1045.138665077422
# Mean IAT for evaded packets: 240.9797353842484
# Median IAT for Detected Packets: 801.0864257812
# Median IAT for evaded packets: 246.04797363279997
# ----------------------------
# ID: 1087.0
# Overall Mean IAT: 655.4093235402056
# Overall Median IAT: 241.994857788
#
# Mean IAT for Detected Packets: 1188.977707741628
# Mean IAT for evaded packets: 241.7574123460053
# Median IAT for Detected Packets: 975.01277923575
# Median IAT for evaded packets: 247.59769439695
# ----------------------------
# ID: 1088.0
# Overall Mean IAT: 240.06422583716838
# Overall Median IAT: 237.94174194329997
#
# Mean IAT for Detected Packets: 247.620480621842
# Mean IAT for evaded packets: 224.60641087708512
# Median IAT for Detected Packets: 247.95532226560002
# Median IAT for evaded packets: 231.98127746580002
# ----------------------------
# ID: 1201.0
# Overall Mean IAT: 229.9705396677065
# Overall Median IAT: 227.928161621
#
# Mean IAT for Detected Packets: nan
# Mean IAT for evaded packets: 250.10108947749998
# Median IAT for Detected Packets: nan
# Median IAT for evaded packets: 250.10108947749998
# ----------------------------
# ID: 1264.0
# Overall Mean IAT: 347.0182922878874
# Overall Median IAT: 241.994857788
#
# Mean IAT for Detected Packets: 530.9568807856527
# Mean IAT for evaded packets: 237.3527078066901
# Median IAT for Detected Packets: 320.9114074707
# Median IAT for evaded packets: 240.0875091552
# ----------------------------
# ID: 1349.0
# Overall Mean IAT: 242.19792084459132
# Overall Median IAT: 239.1338348388
#
# Mean IAT for Detected Packets: 224.4360042067717
# Mean IAT for evaded packets: 234.55769961113086
# Median IAT for Detected Packets: 227.928161621
# Median IAT for evaded packets: 233.88862609859999
# ----------------------------
# ID: 1440.0
# Overall Mean IAT: 694.0921147663884
# Overall Median IAT: 293.37406158445
#
# Mean IAT for Detected Packets: 1010.0406350440835
# Mean IAT for evaded packets: 300.64582824702
# Median IAT for Detected Packets: 511.88468933100006
# Median IAT for evaded packets: 247.95532226560002
# ----------------------------
# ID: 1442.0
# Overall Mean IAT: 262.2852077731351
# Overall Median IAT: 252.0084381103
#
# Mean IAT for Detected Packets: 185.9664916992
# Mean IAT for evaded packets: 251.34285291030835
# Median IAT for Detected Packets: 185.9664916992
# Median IAT for evaded packets: 252.0084381103
# ----------------------------
# ID: 1520.0
# Overall Mean IAT: 431.0933924511093
# Overall Median IAT: 134.9449157714
#
# Mean IAT for Detected Packets: 974.2004004906082
# Mean IAT for evaded packets: 188.58909606926667
# Median IAT for Detected Packets: 864.9826049804
# Median IAT for evaded packets: 186.92016601560002
# ----------------------------
# ID: 1680.0
# Overall Mean IAT: 454.393336147128
# Overall Median IAT: 247.0016479492
#
# Mean IAT for Detected Packets: 2077.3172378539534
# Mean IAT for evaded packets: 317.7881240844234
# Median IAT for Detected Packets: 2383.9473724365
# Median IAT for evaded packets: 284.43336486809994
# ----------------------------

# %%
group
# Out:
#             ID  DLC       Payload         IAT  Packet Type  Prediction  \
# 119     1680.0  8.0  2.686583e+09  240.087509          0.0           0
# 314     1680.0  8.0  2.686583e+09  245.809555          0.0           0
# 509     1680.0  8.0  2.686583e+09  248.193741          0.0           0
# 704     1680.0  8.0  2.686583e+09  244.855881          0.0           0
# 899     1680.0  8.0  2.686583e+09  255.107880          0.0           0
# ...        ...  ...           ...         ...          ...         ...
# 146273  1680.0  8.0  2.686517e+09  242.948532          0.0           0
# 146532  1680.0  8.0  2.686517e+09  244.140625          0.0           0
# 146796  1680.0  8.0  2.686517e+09  241.994858          0.0           0
# 147064  1680.0  8.0  2.686517e+09  247.955322          0.0           0
# 147333  1680.0  8.0  2.686517e+09  244.140625          0.0           0
#
#         Correctly Predicted
# 119                       1
# 314                       1
# 509                       1
# 704                       1
# 899                       1
# ...                     ...
# 146273                    1
# 146532                    1
# 146796                    1
# 147064                    1
# 147333                    1
#
# [602 rows x 7 columns]

# %%
X_test_results.to_csv('results.csv', index = False)

# %%
X_test_results
# Out:
#             ID  DLC       Payload         IAT  Packet Type  Prediction  \
# 0        848.0  8.0  3.716925e+17    0.000000          0.0           0
# 1        704.0  8.0  1.441152e+18  221.014023          0.0           1
# 2       1072.0  8.0  0.000000e+00  553.846359          0.0           1
# 3       1201.0  8.0  0.000000e+00  237.941742          0.0           0
# 4        497.0  8.0  0.000000e+00  248.193741          0.0           0
# ...        ...  ...           ...         ...          ...         ...
# 147457   608.0  8.0  3.202177e+18  237.941742          0.0           1
# 147458   672.0  8.0  1.177723e+14  236.034393          0.0           1
# 147459   809.0  8.0  9.779705e+18  230.073929          0.0           0
# 147460   880.0  8.0  9.851624e+15  247.001648          0.0           0
# 147461  1087.0  8.0  1.636436e+17  236.988068          0.0           0
#
#         Correctly Predicted
# 0                         1
# 1                         0
# 2                         0
# 3                         1
# 4                         1
# ...                     ...
# 147457                    0
# 147458                    0
# 147459                    1
# 147460                    1
# 147461                    1
#
# [147462 rows x 7 columns]
