# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data_path = 'Adversarial_traffic_Both.csv'

# %%
data = pd.read_csv(data_path)  # Adjust delimiter if needed

def construct_payload(row):
    dlc = int(row["DLC"])  # Number of valid data columns
    data_values = [row[f"Data{i}"] for i in range(1, dlc + 1) if f"Data{i}" in row]
    return "".join(map(str, data_values))

data["Data"] = data.apply(construct_payload, axis=1)
# Keep only the required columns
data = data[["TS", "ID", "DLC", "Data", "Label"]]
## Rename the columns to Timestamp, ID, DLC, Data, and Label
data.columns = ["Timestamp", "ID", "DLC", "Data", "label"]

# Save the transformed data
# data.to_csv("transformed_file.csv", index=False)

# Display the transformed DataFrame
data.head()
# Out:
#    Timestamp   ID  DLC              Data  label
# 0   0.000000  2fb    8  de3de7fc77d18619      2
# 1   0.005492  643    8  de5f417c9b4d34db      2
# 2   0.011240  140    8  000000001c072628      0
# 3   0.016786  6df    8  05b06567dfdff49d      2
# 4   0.017052  316    8  052174092120006f      0

# %%
hex_to_dec = lambda x: int(str(x), 16)

def transform_data(data):

    data['ID'] = data['ID'].apply(hex_to_dec)
    data['Data'] = data['Data'].apply(hex_to_dec)

    return data

data = transform_data(data)

# %%
data.head()
# Out:
#    Timestamp    ID  DLC                  Data  label
# 0   0.000000   763    8  16014210921527346713      2
# 1   0.005492  1603    8  16023598002644792539      2
# 2   0.011240   320    8             470230568      0
# 3   0.016786  1759    8    409939062902748317      2
# 4   0.017052   790    8    369704226980364399      0

# %%
data['label'].replace(2,1, inplace=True)
data['label'].replace(3,1, inplace=True)
data.head()
# Out:
# /var/folders/pw/3vr89zzj1xvbzvtk1yfz9kkc0000gn/T/ipykernel_19357/3424221442.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(2,1, inplace=True)
# /var/folders/pw/3vr89zzj1xvbzvtk1yfz9kkc0000gn/T/ipykernel_19357/3424221442.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['label'].replace(3,1, inplace=True)
#    Timestamp    ID  DLC                  Data  label
# 0   0.000000   763    8  16014210921527346713      1
# 1   0.005492  1603    8  16023598002644792539      1
# 2   0.011240   320    8             470230568      0
# 3   0.016786  1759    8    409939062902748317      1
# 4   0.017052   790    8    369704226980364399      0

# %%
def split_into_windows(df, window_size):
    """
    Split dataset into windows of a given size and assign a label to each window.
    
    Args:
        df (pd.DataFrame): Input dataframe.
        window_size (float): Window size in seconds.
        
    Returns:
        list: List of windowed dataframes.
        list: List of labels for each window (1 if any data point in the window is 1, else 0).
        int: Number of windows.
    """
    start_time = df['Timestamp'].min()
    end_time = df['Timestamp'].max()
    
    windows = []
    window_labels = []  # To store the label for each window
    current_time = start_time
    
    while current_time <= end_time:
        # Extract data for the current window
        window = df[(df['Timestamp'] >= current_time) & 
                    (df['Timestamp'] < current_time + window_size)]
        
        if not window.empty:
            windows.append(window)
            
            # Assign window label: 1 if any label is 1 in the window, else 0
            if (window['label'] == 1).any():
                window_labels.append(1)
            else:
                window_labels.append(0)
        
        # Move to next window
        current_time += window_size
    
    return windows, window_labels, len(windows)

def calculate_entropy(windows):
    """
    Calculate entropy for each window.
    
    Args:
        windows (list): List of windowed dataframes.
        
    Returns:
        list: List of entropy values for each window.
    """
    entropies = []
    
    for window in windows:
        # Count unique combinations of Identifier, Data Length Code, and Data
        counts = window.groupby(['ID', 'DLC', 'Data']).size()
        total = counts.sum()
        
        if total > 0:
            # Compute probability
            probabilities = counts / total
            
            # Calculate entropy using the definition
            entropy = -np.sum(probabilities * np.log2(probabilities))
            entropies.append(entropy)
    
    return entropies

# %%
# entropy_dict = {}  # Dictionary to store entropy values by window size
# window_labels_dict = {}  # Stores window labels by window size

# window_sizes = [1, 0.5, 0.1]  # in seconds
# for window_size in window_sizes:
#     windows, window_labels, num_windows = split_into_windows(benign_data, window_size)
#     entropies = calculate_entropy(windows)
    
#     # Store entropy values in dictionary
#     entropy_dict[window_size] = entropies
#     window_labels_dict[window_size] = window_labels

    
#     print(f"Window size: {window_size} seconds")
#     print(f"Number of windows: {num_windows}")
#     print(f"Average entropy: {np.mean(entropies):.4f}\n")

# # Example: Access entropy values later
# print(entropy_dict[1])  # Entropy values for window size 1 second


def plot_entropy(entropy_dict, window_labels_dict, show_labels=True):
    """
    Plots entropy across time windows. If show_labels is True, creates separate plots 
    for each window size, distinguishing attack (label=1) and benign (label=0) windows.

    Args:
        entropy_dict (dict): Dictionary mapping window size to entropy values.
        window_labels_dict (dict): Dictionary mapping window size to window labels.
        show_labels (bool): Whether to plot attack and benign windows separately.
    """
    
    if show_labels:
        for window_size, entropies in entropy_dict.items():
            labels = window_labels_dict[window_size]
            x = np.arange(len(entropies))  # X-axis: Window indices
            
            attack_indices = [idx for idx, lbl in enumerate(labels) if lbl == 1]
            benign_indices = [idx for idx, lbl in enumerate(labels) if lbl == 0]

            plt.figure(figsize=(10, 5))
            
            plt.scatter(attack_indices, [entropies[idx] for idx in attack_indices], 
                        color='red', label='Attack', marker='x')

            plt.scatter(benign_indices, [entropies[idx] for idx in benign_indices], 
                        color='blue', label='Benign', marker='o')

            plt.title(f'Entropy Across Time Windows - Window Size {window_size}s')
            plt.xlabel('Window Index')
            plt.ylabel('Entropy')
            plt.legend()
            plt.grid(True)
            plt.show()

    else:
        plt.figure(figsize=(12, 6))
        colors = ['blue', 'green', 'red']  # Colors for each window size
        
        for i, (window_size, entropies) in enumerate(entropy_dict.items()):
            x = np.arange(len(entropies))  # X-axis: Window indices
            plt.plot(x, entropies, label=f'Window size: {window_size}s', 
                     color=colors[i % len(colors)], marker='o', linestyle='-')

        #
        plt.xlabel('Window Index')
        plt.ylabel('Entropy')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
entropy_dict = {}  # Dictionary to store entropy values by window size
window_labels_dict = {}  # Stores window labels by window size

window_sizes = [1, 0.5, 0.1]  # in seconds
for window_size in window_sizes:
    windows, window_labels, num_windows = split_into_windows(data, window_size)
    entropies = calculate_entropy(windows)
    
    # Store entropy values in dictionary
    entropy_dict[window_size] = entropies
    window_labels_dict[window_size] = window_labels

    
    print(f"Window size: {window_size} seconds")
    print(f"Number of windows: {num_windows}")
    print(f"Average entropy: {np.mean(entropies):.4f}\n")
# Out:
# Window size: 1 seconds
# Number of windows: 67
# Average entropy: 7.5850
#
# Window size: 0.5 seconds
# Number of windows: 134
# Average entropy: 7.0391
#
# Window size: 0.1 seconds
# Number of windows: 669
# Average entropy: 5.6298

# %%
plot_entropy(entropy_dict, window_labels_dict, show_labels=True)

# %%
# entropy_dict[1]

# %%
# entropy_dict

# %%
## Get indices where the below list has value 1
window_1_labels = window_labels_dict[1]
window05_labels = window_labels_dict[0.5]
window01_labels = window_labels_dict[0.1]

# %%
print("Length of window_1: ", len(window_1_labels))
print("Length of window05: ", len(window05_labels))
print("Length of window01: ", len(window01_labels))
# Out:
# Length of window_1:  67
# Length of window05:  134
# Length of window01:  669

# %%
train_size = 0.3

train_window_01_labels, test_window_01_labels = window01_labels[0:int(train_size*len(window01_labels))], window01_labels[int(train_size*len(window01_labels)):]
train_window05_labels, test_window05_labels = window05_labels[0:int(train_size*len(window05_labels))], window05_labels[int(train_size*len(window05_labels)):]
train_window1_labels, test_window1_labels = window_1_labels[0:int(train_size*len(window_1_labels))], window_1_labels[int(train_size*len(window_1_labels)):]

train_window_01 = entropy_dict[0.1][0:int(train_size*len(window01_labels))]
benign_indices_01 = [idx for idx, lbl in enumerate(window01_labels[:int(train_size*len(window01_labels))]) if lbl == 0]
attack_indices_01 = [idx for idx, lbl in enumerate(window01_labels[:int(train_size*len(window01_labels))]) if lbl == 1]
train_window_01_benign = [train_window_01[i] for i in benign_indices_01]
test_window_01 = entropy_dict[0.1][int(train_size*len(window01_labels)):]

train_window_05 = entropy_dict[0.5][0:int(train_size*len(window05_labels))]
benign_indices_05 = [idx for idx, lbl in enumerate(window05_labels[:int(train_size*len(window05_labels))]) if lbl == 0]
attack_indices_05 = [idx for idx, lbl in enumerate(window05_labels[:int(train_size*len(window05_labels))]) if lbl == 1]
train_window_05_benign = [train_window_05[i] for i in benign_indices_05]
test_window_05 = entropy_dict[0.5][int(train_size*len(window05_labels)):]

train_window_1 = entropy_dict[1][0:int(train_size*len(window_1_labels))]
benign_indices_1 = [idx for idx, lbl in enumerate(window_1_labels[:int(train_size*len(window_1_labels))]) if lbl == 0]
attack_indices_01 = [idx for idx, lbl in enumerate(window_1_labels[:int(train_size*len(window_1_labels))]) if lbl == 1]
train_window_1_benign = [train_window_1[i] for i in benign_indices_1]
test_window_1 = entropy_dict[1][int(train_size*len(window_1_labels)):]

print("Train window 0.5: ", len(train_window_05_benign))
print("Test window 0.5: ", len(test_window_05))
print('\n')

print("Train window 0.1: ", len(train_window_01_benign))
print("Test window 0.1: ", len(test_window_01))
print('\n')

print("Train window 1: ", len(train_window_1_benign))
print("Test window 1: ", len(test_window_1))
print('\n')
# Out:
# Train window 0.5:  14
# Test window 0.5:  94
#
#
# Train window 0.1:  76
# Test window 0.1:  469
#
#
# Train window 1:  6
# Test window 1:  47

# %%
# attack_indices_1 = [idx for idx, lbl in enumerate(window_1_labels) if lbl == 1]
# attack_indices_05 = [idx for idx, lbl in enumerate(window05_labels) if lbl == 1]
# attack_indices_01 = [idx for idx, lbl in enumerate(window01_labels) if lbl == 1]

# train_indices_1 = [idx for idx, lbl in enumerate(train_window_1) if lbl == 0]
# train_indices_05 = [idx for idx, lbl in enumerate(train_window_05) if lbl == 0]
# train_indices_01 = [idx for idx, lbl in enumerate(train_window_01) if lbl == 0]

# %%
## Get the entropy values for the benign indices
train_entropy_1 = [entropy_dict[1][i] for i in  benign_indices_1]
train_entropy_05 = [entropy_dict[0.5][i] for i in  benign_indices_05]
train_entropy_01 = [entropy_dict[0.1][i] for i in  benign_indices_01]

## Get the entropy values for the attack indices
train_entropy_attack_1 = [entropy_dict[1][i] for i in  attack_indices_01]
train_entropy_attack_05 = [entropy_dict[0.5][i] for i in  attack_indices_05]
train_entropy_attack_01 = [entropy_dict[0.1][i] for i in  attack_indices_01]

train_entropy_1_mean, train_entropy_1_std = np.mean(train_entropy_1), np.std(train_entropy_1)
train_entropy_05_mean, train_entropy_05_std = np.mean(train_entropy_05), np.std(train_entropy_05)
train_entropy_01_mean, train_entropy_01_std = np.mean(train_entropy_01), np.std(train_entropy_01)


print(f"Window size: 1 second")
print(f"Train entropy mean and std-dev: {train_entropy_1_mean:.4f}, {train_entropy_1_std:.4f}") 
print('\n')
print(f"Window size: 0.5 second")
print(f"Train entropy mean and std-dev: {train_entropy_05_mean:.4f}, {train_entropy_05_std:.4f}")
print('\n')
print(f"Window size: 0.1 second")
print(f"Train entropy mean and std-dev: {train_entropy_01_mean:.4f}, {train_entropy_01_std:.4f}")
# Out:
# Window size: 1 second
# Train entropy mean and std-dev: 7.3757, 0.1175
#
#
# Window size: 0.5 second
# Train entropy mean and std-dev: 7.0039, 0.1134
#
#
# Window size: 0.1 second
# Train entropy mean and std-dev: 5.9657, 0.1595

# %%
plt.hist(train_entropy_1, bins = 20, alpha = 0.5, label = 'Benign')
plt.hist(train_entropy_attack_1, bins = 20, alpha = 0.5, label = 'Attack')
plt.legend()
plt.title('Entropy distribution for 1 second window')
plt.show()

# %%
plt.hist(train_entropy_05, bins = 20, alpha = 0.5, label = 'Benign')
plt.hist(train_entropy_attack_05, bins = 20, alpha = 0.5, label = 'Attack')
plt.legend()
plt.title('Entropy distribution for 0.5 second window')
plt.show()

# %%
plt.hist(train_entropy_01, bins = 20, alpha = 0.5, label = 'Benign')
plt.hist(train_entropy_attack_01, bins = 20, alpha = 0.5, label = 'Attack')
plt.legend()
plt.title('Entropy distribution for 0.1 second window')
plt.show()

# %%
# test_attack_indices_1 = [idx for idx, lbl in enumerate(test_window1) if lbl == 1]
# test_attack_indices_05 = [idx for idx, lbl in enumerate(test_window05) if lbl == 1]
# attack_indices_01 = [idx for idx, lbl in enumerate(test_window_01) if lbl == 1]

# test_benign_indices_1 = [idx for idx, lbl in enumerate(test_window1) if lbl == 0]
# test_benign_indices_05 = [idx for idx, lbl in enumerate(test_window05) if lbl == 0]
# test_benign_indices_01 = [idx for idx, lbl in enumerate(test_window_01) if lbl == 0]

# train_benign_indices_1 = [idx for idx, lbl in enumerate(train_window1) if lbl == 0]
# train_bengin_indices_05 = [idx for idx, lbl in enumerate(train_window05) if lbl == 0]
# train_benign_indices_01 = [idx for idx, lbl in enumerate(train_window_01) if lbl == 0]

# ## Get the entropy values for the benign indices
# train_entropy_1 = [entropy_dict[1][i] for i in  train_benign_indices_1]
# train_entropy_05 = [entropy_dict[0.5][i] for i in  train_bengin_indices_05]
# train_entropy_01 = [entropy_dict[0.1][i] for i in  train_benign_indices_01]

# ## Get the entropy values for the attack indices
# entropy_attack_1 = [entropy_dict[1][i] for i in  attack_indices_1]
# entropy_attack_05 = [entropy_dict[0.5][i] for i in  attack_indices_05]
# entropy_attack_01 = [entropy_dict[0.1][i] for i in  attack_indices_01]

# entropy_1_mean, entropy_1_std, entropy_attack_1_mean, entropy_attack_1_std = np.mean(entropy_1), np.std(entropy_1), np.mean(entropy_attack_1), np.std(entropy_attack_1)
# entropy_05_mean, entropy_05_std, entropy_attack_05_mean, entropy_attack_05_std = np.mean(entropy_05), np.std(entropy_05), np.mean(entropy_attack_05), np.std(entropy_attack_05)
# entropy_01_mean, entropy_01_std, entropy_attack_01_mean, entropy_attack_01_std = np.mean(entropy_01), np.std(entropy_01), np.mean(entropy_attack_01), np.std(entropy_attack_01)

# %%
## threshold = [mean - k*std_dev, mean + k*std_dev]


def detect_attack(entropy, threshold):
    """
    Detects attack based on entropy values and threshold.
    
    Args:
        entropy (list): Entropy list.
        threshold (list): Lower and upper threshold values.
        
    Returns:
        predicted_labels (list): List of predicted labels (1 if attack, else 0).
    """
    predicted_labels = []
    
    for e in entropy:
        if e < threshold[0] or e > threshold[1]:
            predicted_labels.append(1)
        else:
            predicted_labels.append(0)
    
    return predicted_labels

k_vals = [0.1, 0.2, 0.5, 0.8, 1, 1.5, 2, 2.5, 3]

for k in k_vals:
    threshold_1 = [train_entropy_1_mean - k*train_entropy_1_std, train_entropy_1_mean + k*train_entropy_1_std]
    threshold_05 = [train_entropy_05_mean - k*train_entropy_05_std, train_entropy_05_mean + k*train_entropy_05_std] 
    threshold_01 = [train_entropy_01_mean - k*train_entropy_01_std, train_entropy_01_mean + k*train_entropy_01_std]
    
    print(f"Threshold for k = {k}")
    print('\n')

    print(f"Window size: 1 second")
    print(f"Threshold: {threshold_1}")

    predicted_labels = detect_attack(test_window_1, threshold_1)
    print("Accuracy:", accuracy_score(test_window1_labels, predicted_labels))
    print("classification Report")
    print(classification_report(test_window1_labels, predicted_labels))
    
    print(f"Window size: 0.5 second")
    print(f"Threshold: {threshold_05}")

    predicted_labels = detect_attack(test_window_05, threshold_05)
    print("Accuracy", accuracy_score(test_window05_labels, predicted_labels))
    print("classification Report")
    print(classification_report(test_window05_labels, predicted_labels))

    tn, fp, fn, tp = confusion_matrix(test_window05_labels, predicted_labels).ravel()

# Count of real positives and negatives
    total_positives = tp + fn
    total_negatives = tn + fp

    # Print the results
    print(f"True Positives (TP): {tp} / {total_positives} (Total Real Positives)")
    print(f"False Positives (FP): {fp} / {total_positives} (Total Real Positives)")
    print(f"True Negatives (TN): {tn} / {total_negatives} (Total Real Negatives)")
    print(f"False Negatives (FN): {fn} / {total_negatives} (Total Real Negatives)")
    print('\n')



    print(f"Window size: 0.1 second")
    print(f"Threshold: {threshold_01}")
    predicted_labels = detect_attack(test_window_01, threshold_01)
    print("Accuracy:",accuracy_score(test_window_01_labels, predicted_labels))
    print("classification Report")
    print(classification_report(test_window_01_labels, predicted_labels))

    tn, fp, fn, tp = confusion_matrix(test_window_01_labels, predicted_labels).ravel()

# Count of real positives and negatives
    total_positives = tp + fn
    total_negatives = tn + fp

    # Print the results
    print(f"True Positives (TP): {tp} / {total_positives} (Total Real Positives)")
    print(f"False Positives (FP): {fp} / {total_positives} (Total Real Positives)")
    print(f"True Negatives (TN): {tn} / {total_negatives} (Total Real Negatives)")
    print(f"False Negatives (FN): {fn} / {total_negatives} (Total Real Negatives)")
    print('\n\n\n')
# Out:
# Threshold for k = 0.1
#
#
# Window size: 1 second
# Threshold: [7.363938261438611, 7.387441695993865]
# Accuracy: 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      0.14      0.20        14
#            1       0.71      0.88      0.78        33
#
#     accuracy                           0.66        47
#    macro avg       0.52      0.51      0.49        47
# weighted avg       0.60      0.66      0.61        47
#
# Window size: 0.5 second
# Threshold: [6.992590367531115, 7.015260664240278]
# Accuracy 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.11      0.20        35
#            1       0.65      0.98      0.78        59
#
#     accuracy                           0.66        94
#    macro avg       0.73      0.55      0.49        94
# weighted avg       0.71      0.66      0.57        94
#
# True Positives (TP): 58 / 59 (Total Real Positives)
# False Positives (FP): 31 / 59 (Total Real Positives)
# True Negatives (TN): 4 / 35 (Total Real Negatives)
# False Negatives (FN): 1 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.9497424904218805, 5.981639985137005]
# Accuracy: 0.5884861407249466
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.08      0.14       206
#            1       0.58      0.99      0.73       263
#
#     accuracy                           0.59       469
#    macro avg       0.71      0.53      0.44       469
# weighted avg       0.69      0.59      0.47       469
#
# True Positives (TP): 260 / 263 (Total Real Positives)
# False Positives (FP): 190 / 263 (Total Real Positives)
# True Negatives (TN): 16 / 206 (Total Real Negatives)
# False Negatives (FN): 3 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 0.2
#
#
# Window size: 1 second
# Threshold: [7.352186544160985, 7.399193413271491]
# Accuracy: 0.6808510638297872
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      0.21      0.29        14
#            1       0.72      0.88      0.79        33
#
#     accuracy                           0.68        47
#    macro avg       0.58      0.55      0.54        47
# weighted avg       0.64      0.68      0.64        47
#
# Window size: 0.5 second
# Threshold: [6.981255219176533, 7.02659581259486]
# Accuracy 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.17      0.27        35
#            1       0.66      0.95      0.78        59
#
#     accuracy                           0.66        94
#    macro avg       0.66      0.56      0.53        94
# weighted avg       0.66      0.66      0.59        94
#
# True Positives (TP): 56 / 59 (Total Real Positives)
# False Positives (FP): 29 / 59 (Total Real Positives)
# True Negatives (TN): 6 / 35 (Total Real Negatives)
# False Negatives (FN): 3 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.933793743064319, 5.997588732494567]
# Accuracy: 0.6140724946695096
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.16      0.27       206
#            1       0.60      0.97      0.74       263
#
#     accuracy                           0.61       469
#    macro avg       0.70      0.56      0.50       469
# weighted avg       0.69      0.61      0.53       469
#
# True Positives (TP): 255 / 263 (Total Real Positives)
# False Positives (FP): 173 / 263 (Total Real Positives)
# True Negatives (TN): 33 / 206 (Total Real Negatives)
# False Negatives (FN): 8 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 0.5
#
#
# Window size: 1 second
# Threshold: [7.3169313923281045, 7.434448565104372]
# Accuracy: 0.6808510638297872
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.47      0.50      0.48        14
#            1       0.78      0.76      0.77        33
#
#     accuracy                           0.68        47
#    macro avg       0.62      0.63      0.63        47
# weighted avg       0.69      0.68      0.68        47
#
# Window size: 0.5 second
# Threshold: [6.947249774112788, 7.060601257658605]
# Accuracy 0.6276595744680851
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.31      0.39        35
#            1       0.67      0.81      0.73        59
#
#     accuracy                           0.63        94
#    macro avg       0.58      0.56      0.56        94
# weighted avg       0.60      0.63      0.60        94
#
# True Positives (TP): 48 / 59 (Total Real Positives)
# False Positives (FP): 24 / 59 (Total Real Positives)
# True Negatives (TN): 11 / 35 (Total Real Negatives)
# False Negatives (FN): 11 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.885947500991633, 6.045434974567253]
# Accuracy: 0.6886993603411514
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.35      0.50       206
#            1       0.65      0.95      0.77       263
#
#     accuracy                           0.69       469
#    macro avg       0.75      0.65      0.64       469
# weighted avg       0.74      0.69      0.65       469
#
# True Positives (TP): 250 / 263 (Total Real Positives)
# False Positives (FP): 133 / 263 (Total Real Positives)
# True Negatives (TN): 73 / 206 (Total Real Negatives)
# False Negatives (FN): 13 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 0.8
#
#
# Window size: 1 second
# Threshold: [7.281676240495225, 7.469703716937252]
# Accuracy: 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      0.50      0.47        14
#            1       0.77      0.73      0.75        33
#
#     accuracy                           0.66        47
#    macro avg       0.61      0.61      0.61        47
# weighted avg       0.67      0.66      0.67        47
#
# Window size: 0.5 second
# Threshold: [6.913244329049043, 7.09460670272235]
# Accuracy 0.6170212765957447
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.49      0.49      0.49        35
#            1       0.69      0.69      0.69        59
#
#     accuracy                           0.62        94
#    macro avg       0.59      0.59      0.59        94
# weighted avg       0.62      0.62      0.62        94
#
# True Positives (TP): 41 / 59 (Total Real Positives)
# False Positives (FP): 18 / 59 (Total Real Positives)
# True Negatives (TN): 17 / 35 (Total Real Negatives)
# False Negatives (FN): 18 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.838101258918947, 6.093281216639939]
# Accuracy: 0.7739872068230277
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.57      0.69       206
#            1       0.74      0.93      0.82       263
#
#     accuracy                           0.77       469
#    macro avg       0.80      0.75      0.76       469
# weighted avg       0.79      0.77      0.76       469
#
# True Positives (TP): 245 / 263 (Total Real Positives)
# False Positives (FP): 88 / 263 (Total Real Positives)
# True Negatives (TN): 118 / 206 (Total Real Negatives)
# False Negatives (FN): 18 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 1
#
#
# Window size: 1 second
# Threshold: [7.258172805939972, 7.493207151492505]
# Accuracy: 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      0.57      0.50        14
#            1       0.79      0.70      0.74        33
#
#     accuracy                           0.66        47
#    macro avg       0.62      0.63      0.62        47
# weighted avg       0.69      0.66      0.67        47
#
# Window size: 0.5 second
# Threshold: [6.890574032339879, 7.117276999431514]
# Accuracy 0.648936170212766
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.52      0.71      0.60        35
#            1       0.78      0.61      0.69        59
#
#     accuracy                           0.65        94
#    macro avg       0.65      0.66      0.64        94
# weighted avg       0.69      0.65      0.65        94
#
# True Positives (TP): 36 / 59 (Total Real Positives)
# False Positives (FP): 10 / 59 (Total Real Positives)
# True Negatives (TN): 25 / 35 (Total Real Negatives)
# False Negatives (FN): 23 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.806203764203823, 6.125178711355063]
# Accuracy: 0.8123667377398721
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77       206
#            1       0.79      0.90      0.84       263
#
#     accuracy                           0.81       469
#    macro avg       0.82      0.80      0.80       469
# weighted avg       0.82      0.81      0.81       469
#
# True Positives (TP): 237 / 263 (Total Real Positives)
# False Positives (FP): 62 / 263 (Total Real Positives)
# True Negatives (TN): 144 / 206 (Total Real Negatives)
# False Negatives (FN): 26 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 1.5
#
#
# Window size: 1 second
# Threshold: [7.199414219551838, 7.551965737880638]
# Accuracy: 0.6170212765957447
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.79      0.55        14
#            1       0.86      0.55      0.67        33
#
#     accuracy                           0.62        47
#    macro avg       0.64      0.67      0.61        47
# weighted avg       0.73      0.62      0.63        47
#
# Window size: 0.5 second
# Threshold: [6.833898290566971, 7.173952741204422]
# Accuracy 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.53      0.89      0.66        35
#            1       0.89      0.53      0.66        59
#
#     accuracy                           0.66        94
#    macro avg       0.71      0.71      0.66        94
# weighted avg       0.75      0.66      0.66        94
#
# True Positives (TP): 31 / 59 (Total Real Positives)
# False Positives (FP): 4 / 59 (Total Real Positives)
# True Negatives (TN): 31 / 35 (Total Real Negatives)
# False Negatives (FN): 28 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.726460027416013, 6.204922448142873]
# Accuracy: 0.8742004264392325
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87       206
#            1       0.94      0.83      0.88       263
#
#     accuracy                           0.87       469
#    macro avg       0.87      0.88      0.87       469
# weighted avg       0.88      0.87      0.87       469
#
# True Positives (TP): 219 / 263 (Total Real Positives)
# False Positives (FP): 15 / 263 (Total Real Positives)
# True Negatives (TN): 191 / 206 (Total Real Negatives)
# False Negatives (FN): 44 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 2
#
#
# Window size: 1 second
# Threshold: [7.140655633163704, 7.610724324268772]
# Accuracy: 0.6170212765957447
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      0.93      0.59        14
#            1       0.94      0.48      0.64        33
#
#     accuracy                           0.62        47
#    macro avg       0.69      0.71      0.62        47
# weighted avg       0.79      0.62      0.63        47
#
# Window size: 0.5 second
# Threshold: [6.777222548794063, 7.23062848297733]
# Accuracy 0.6276595744680851
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.97      0.66        35
#            1       0.96      0.42      0.59        59
#
#     accuracy                           0.63        94
#    macro avg       0.73      0.70      0.62        94
# weighted avg       0.79      0.63      0.62        94
#
# True Positives (TP): 25 / 59 (Total Real Positives)
# False Positives (FP): 1 / 59 (Total Real Positives)
# True Negatives (TN): 34 / 35 (Total Real Negatives)
# False Negatives (FN): 34 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.646716290628203, 6.284666184930683]
# Accuracy: 0.8528784648187633
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.86       206
#            1       0.99      0.75      0.85       263
#
#     accuracy                           0.85       469
#    macro avg       0.87      0.87      0.85       469
# weighted avg       0.89      0.85      0.85       469
#
# True Positives (TP): 196 / 263 (Total Real Positives)
# False Positives (FP): 2 / 263 (Total Real Positives)
# True Negatives (TN): 204 / 206 (Total Real Negatives)
# False Negatives (FN): 67 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 2.5
#
#
# Window size: 1 second
# Threshold: [7.0818970467755715, 7.669482910656905]
# Accuracy: 0.574468085106383
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        14
#            1       1.00      0.39      0.57        33
#
#     accuracy                           0.57        47
#    macro avg       0.71      0.70      0.57        47
# weighted avg       0.82      0.57      0.57        47
#
# Window size: 0.5 second
# Threshold: [6.7205468070211545, 7.287304224750239]
# Accuracy 0.5957446808510638
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.65        35
#            1       1.00      0.36      0.53        59
#
#     accuracy                           0.60        94
#    macro avg       0.74      0.68      0.59        94
# weighted avg       0.81      0.60      0.57        94
#
# True Positives (TP): 21 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 38 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.566972553840393, 6.364409921718493]
# Accuracy: 0.8102345415778252
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82       206
#            1       0.99      0.67      0.80       263
#
#     accuracy                           0.81       469
#    macro avg       0.85      0.83      0.81       469
# weighted avg       0.86      0.81      0.81       469
#
# True Positives (TP): 175 / 263 (Total Real Positives)
# False Positives (FP): 1 / 263 (Total Real Positives)
# True Negatives (TN): 205 / 206 (Total Real Negatives)
# False Negatives (FN): 88 / 206 (Total Real Negatives)
#
#
#
#
# Threshold for k = 3
#
#
# Window size: 1 second
# Threshold: [7.023138460387438, 7.728241497045039]
# Accuracy: 0.48936170212765956
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        14
#            1       1.00      0.27      0.43        33
#
#     accuracy                           0.49        47
#    macro avg       0.68      0.64      0.48        47
# weighted avg       0.81      0.49      0.46        47
#
# Window size: 0.5 second
# Threshold: [6.663871065248245, 7.343979966523148]
# Accuracy 0.5106382978723404
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      1.00      0.60        35
#            1       1.00      0.22      0.36        59
#
#     accuracy                           0.51        94
#    macro avg       0.72      0.61      0.48        94
# weighted avg       0.79      0.51      0.45        94
#
# True Positives (TP): 13 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 46 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.487228817052583, 6.444153658506303]
# Accuracy: 0.7761194029850746
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       206
#            1       1.00      0.60      0.75       263
#
#     accuracy                           0.78       469
#    macro avg       0.83      0.80      0.77       469
# weighted avg       0.85      0.78      0.77       469
#
# True Positives (TP): 158 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 105 / 206 (Total Real Negatives)

# %%
def detect_attack(entropy, threshold):
    """
    Detects attack based on entropy values and threshold.
    
    Args:
        entropy (list): Entropy list.
        threshold (list): Lower and upper threshold values.
        
    Returns:
        predicted_labels (list): List of predicted labels (1 if attack, else 0).
    """
    predicted_labels = []
    
    for e in entropy:
        if e < threshold[0] or e > threshold[1]:
            predicted_labels.append(1)
        else:
            predicted_labels.append(0)
    
    return predicted_labels

k_vals = [0.1, 0.2, 0.5, 0.8, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 9, 9.5, 10]

best_accuracy_1 = 0
best_k_1 = 0
best_accuracy_05 = 0
best_k_05 = 0
best_accuracy_01 = 0
best_k_01 = 0

for k in k_vals:
    threshold_1 = [train_entropy_1_mean - k*train_entropy_1_std, train_entropy_1_mean + k*train_entropy_1_std]
    threshold_05 = [train_entropy_05_mean - k*train_entropy_05_std, train_entropy_05_mean + k*train_entropy_05_std] 
    threshold_01 = [train_entropy_01_mean - k*train_entropy_01_std, train_entropy_01_mean + k*train_entropy_01_std]
    
    print(f"Threshold for k = {k}")
    print('\n')

    print(f"Window size: 1 second")
    print(f"Threshold: {threshold_1}")

    predicted_labels = detect_attack(test_window_1, threshold_1)
    accuracy_1 = accuracy_score(test_window1_labels, predicted_labels)
    print("Accuracy:", accuracy_1)
    print("classification Report")
    print(classification_report(test_window1_labels, predicted_labels))
    if accuracy_1 > best_accuracy_1:
        best_accuracy_1 = accuracy_1
        best_k_1 = k

    tn, fp, fn, tp = confusion_matrix(test_window1_labels, predicted_labels).ravel()

# Count of real positives and negatives
    total_positives = tp + fn
    total_negatives = tn + fp

    # Print the results
    print(f"True Positives (TP): {tp} / {total_positives} (Total Real Positives)")
    print(f"False Positives (FP): {fp} / {total_positives} (Total Real Positives)")
    print(f"True Negatives (TN): {tn} / {total_negatives} (Total Real Negatives)")
    print(f"False Negatives (FN): {fn} / {total_negatives} (Total Real Negatives)")
    print('\n')


    print(f"Window size: 0.5 second")
    print(f"Threshold: {threshold_05}")

    predicted_labels = detect_attack(test_window_05, threshold_05)
    accuracy_05 = accuracy_score(test_window05_labels, predicted_labels)
    print("Accuracy", accuracy_05)
    print("classification Report")
    print(classification_report(test_window05_labels, predicted_labels))
    if accuracy_05 > best_accuracy_05:
        best_accuracy_05 = accuracy_05
        best_k_05 = k

    tn, fp, fn, tp = confusion_matrix(test_window05_labels, predicted_labels).ravel()

# Count of real positives and negatives
    total_positives = tp + fn
    total_negatives = tn + fp

    # Print the results
    print(f"True Positives (TP): {tp} / {total_positives} (Total Real Positives)")
    print(f"False Positives (FP): {fp} / {total_positives} (Total Real Positives)")
    print(f"True Negatives (TN): {tn} / {total_negatives} (Total Real Negatives)")
    print(f"False Negatives (FN): {fn} / {total_negatives} (Total Real Negatives)")
    print('\n')


    print(f"Window size: 0.1 second")
    print(f"Threshold: {threshold_01}")
    predicted_labels = detect_attack(test_window_01, threshold_01)
    accuracy_01 = accuracy_score(test_window_01_labels, predicted_labels)
    print("Accuracy:", accuracy_01)
    print("classification Report")
    print(classification_report(test_window_01_labels, predicted_labels))
    if accuracy_01 > best_accuracy_01:
        best_accuracy_01 = accuracy_01
        best_k_01 = k

    print('\n')

    tn, fp, fn, tp = confusion_matrix(test_window_01_labels, predicted_labels).ravel()

# Count of real positives and negatives
    total_positives = tp + fn
    total_negatives = tn + fp

    # Print the results
    print(f"True Positives (TP): {tp} / {total_positives} (Total Real Positives)")
    print(f"False Positives (FP): {fp} / {total_positives} (Total Real Positives)")
    print(f"True Negatives (TN): {tn} / {total_negatives} (Total Real Negatives)")
    print(f"False Negatives (FN): {fn} / {total_negatives} (Total Real Negatives)")
    print('\n')


print(f"Best k value for window size 1 second: {best_k_1} with accuracy {best_accuracy_1}")
print(f"Best k value for window size 0.5 second: {best_k_05} with accuracy {best_accuracy_05}")
print(f"Best k value for window size 0.1 second: {best_k_01} with accuracy {best_accuracy_01}")
# Out:
# Threshold for k = 0.1
#
#
# Window size: 1 second
# Threshold: [7.363938261438611, 7.387441695993865]
# Accuracy: 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      0.14      0.20        14
#            1       0.71      0.88      0.78        33
#
#     accuracy                           0.66        47
#    macro avg       0.52      0.51      0.49        47
# weighted avg       0.60      0.66      0.61        47
#
# True Positives (TP): 29 / 33 (Total Real Positives)
# False Positives (FP): 12 / 33 (Total Real Positives)
# True Negatives (TN): 2 / 14 (Total Real Negatives)
# False Negatives (FN): 4 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.992590367531115, 7.015260664240278]
# Accuracy 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.11      0.20        35
#            1       0.65      0.98      0.78        59
#
#     accuracy                           0.66        94
#    macro avg       0.73      0.55      0.49        94
# weighted avg       0.71      0.66      0.57        94
#
# True Positives (TP): 58 / 59 (Total Real Positives)
# False Positives (FP): 31 / 59 (Total Real Positives)
# True Negatives (TN): 4 / 35 (Total Real Negatives)
# False Negatives (FN): 1 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.9497424904218805, 5.981639985137005]
# Accuracy: 0.5884861407249466
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.84      0.08      0.14       206
#            1       0.58      0.99      0.73       263
#
#     accuracy                           0.59       469
#    macro avg       0.71      0.53      0.44       469
# weighted avg       0.69      0.59      0.47       469
#
#
#
# True Positives (TP): 260 / 263 (Total Real Positives)
# False Positives (FP): 190 / 263 (Total Real Positives)
# True Negatives (TN): 16 / 206 (Total Real Negatives)
# False Negatives (FN): 3 / 206 (Total Real Negatives)
#
#
# Threshold for k = 0.2
#
#
# Window size: 1 second
# Threshold: [7.352186544160985, 7.399193413271491]
# Accuracy: 0.6808510638297872
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      0.21      0.29        14
#            1       0.72      0.88      0.79        33
#
#     accuracy                           0.68        47
#    macro avg       0.58      0.55      0.54        47
# weighted avg       0.64      0.68      0.64        47
#
# True Positives (TP): 29 / 33 (Total Real Positives)
# False Positives (FP): 11 / 33 (Total Real Positives)
# True Negatives (TN): 3 / 14 (Total Real Negatives)
# False Negatives (FN): 4 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.981255219176533, 7.02659581259486]
# Accuracy 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.17      0.27        35
#            1       0.66      0.95      0.78        59
#
#     accuracy                           0.66        94
#    macro avg       0.66      0.56      0.53        94
# weighted avg       0.66      0.66      0.59        94
#
# True Positives (TP): 56 / 59 (Total Real Positives)
# False Positives (FP): 29 / 59 (Total Real Positives)
# True Negatives (TN): 6 / 35 (Total Real Negatives)
# False Negatives (FN): 3 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.933793743064319, 5.997588732494567]
# Accuracy: 0.6140724946695096
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.16      0.27       206
#            1       0.60      0.97      0.74       263
#
#     accuracy                           0.61       469
#    macro avg       0.70      0.56      0.50       469
# weighted avg       0.69      0.61      0.53       469
#
#
#
# True Positives (TP): 255 / 263 (Total Real Positives)
# False Positives (FP): 173 / 263 (Total Real Positives)
# True Negatives (TN): 33 / 206 (Total Real Negatives)
# False Negatives (FN): 8 / 206 (Total Real Negatives)
#
#
# Threshold for k = 0.5
#
#
# Window size: 1 second
# Threshold: [7.3169313923281045, 7.434448565104372]
# Accuracy: 0.6808510638297872
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.47      0.50      0.48        14
#            1       0.78      0.76      0.77        33
#
#     accuracy                           0.68        47
#    macro avg       0.62      0.63      0.63        47
# weighted avg       0.69      0.68      0.68        47
#
# True Positives (TP): 25 / 33 (Total Real Positives)
# False Positives (FP): 7 / 33 (Total Real Positives)
# True Negatives (TN): 7 / 14 (Total Real Negatives)
# False Negatives (FN): 8 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.947249774112788, 7.060601257658605]
# Accuracy 0.6276595744680851
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.31      0.39        35
#            1       0.67      0.81      0.73        59
#
#     accuracy                           0.63        94
#    macro avg       0.58      0.56      0.56        94
# weighted avg       0.60      0.63      0.60        94
#
# True Positives (TP): 48 / 59 (Total Real Positives)
# False Positives (FP): 24 / 59 (Total Real Positives)
# True Negatives (TN): 11 / 35 (Total Real Negatives)
# False Negatives (FN): 11 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.885947500991633, 6.045434974567253]
# Accuracy: 0.6886993603411514
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.35      0.50       206
#            1       0.65      0.95      0.77       263
#
#     accuracy                           0.69       469
#    macro avg       0.75      0.65      0.64       469
# weighted avg       0.74      0.69      0.65       469
#
#
#
# True Positives (TP): 250 / 263 (Total Real Positives)
# False Positives (FP): 133 / 263 (Total Real Positives)
# True Negatives (TN): 73 / 206 (Total Real Negatives)
# False Negatives (FN): 13 / 206 (Total Real Negatives)
#
#
# Threshold for k = 0.8
#
#
# Window size: 1 second
# Threshold: [7.281676240495225, 7.469703716937252]
# Accuracy: 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      0.50      0.47        14
#            1       0.77      0.73      0.75        33
#
#     accuracy                           0.66        47
#    macro avg       0.61      0.61      0.61        47
# weighted avg       0.67      0.66      0.67        47
#
# True Positives (TP): 24 / 33 (Total Real Positives)
# False Positives (FP): 7 / 33 (Total Real Positives)
# True Negatives (TN): 7 / 14 (Total Real Negatives)
# False Negatives (FN): 9 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.913244329049043, 7.09460670272235]
# Accuracy 0.6170212765957447
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.49      0.49      0.49        35
#            1       0.69      0.69      0.69        59
#
#     accuracy                           0.62        94
#    macro avg       0.59      0.59      0.59        94
# weighted avg       0.62      0.62      0.62        94
#
# True Positives (TP): 41 / 59 (Total Real Positives)
# False Positives (FP): 18 / 59 (Total Real Positives)
# True Negatives (TN): 17 / 35 (Total Real Negatives)
# False Negatives (FN): 18 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.838101258918947, 6.093281216639939]
# Accuracy: 0.7739872068230277
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.57      0.69       206
#            1       0.74      0.93      0.82       263
#
#     accuracy                           0.77       469
#    macro avg       0.80      0.75      0.76       469
# weighted avg       0.79      0.77      0.76       469
#
#
#
# True Positives (TP): 245 / 263 (Total Real Positives)
# False Positives (FP): 88 / 263 (Total Real Positives)
# True Negatives (TN): 118 / 206 (Total Real Negatives)
# False Negatives (FN): 18 / 206 (Total Real Negatives)
#
#
# Threshold for k = 1
#
#
# Window size: 1 second
# Threshold: [7.258172805939972, 7.493207151492505]
# Accuracy: 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      0.57      0.50        14
#            1       0.79      0.70      0.74        33
#
#     accuracy                           0.66        47
#    macro avg       0.62      0.63      0.62        47
# weighted avg       0.69      0.66      0.67        47
#
# True Positives (TP): 23 / 33 (Total Real Positives)
# False Positives (FP): 6 / 33 (Total Real Positives)
# True Negatives (TN): 8 / 14 (Total Real Negatives)
# False Negatives (FN): 10 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.890574032339879, 7.117276999431514]
# Accuracy 0.648936170212766
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.52      0.71      0.60        35
#            1       0.78      0.61      0.69        59
#
#     accuracy                           0.65        94
#    macro avg       0.65      0.66      0.64        94
# weighted avg       0.69      0.65      0.65        94
#
# True Positives (TP): 36 / 59 (Total Real Positives)
# False Positives (FP): 10 / 59 (Total Real Positives)
# True Negatives (TN): 25 / 35 (Total Real Negatives)
# False Negatives (FN): 23 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.806203764203823, 6.125178711355063]
# Accuracy: 0.8123667377398721
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77       206
#            1       0.79      0.90      0.84       263
#
#     accuracy                           0.81       469
#    macro avg       0.82      0.80      0.80       469
# weighted avg       0.82      0.81      0.81       469
#
#
#
# True Positives (TP): 237 / 263 (Total Real Positives)
# False Positives (FP): 62 / 263 (Total Real Positives)
# True Negatives (TN): 144 / 206 (Total Real Negatives)
# False Negatives (FN): 26 / 206 (Total Real Negatives)
#
#
# Threshold for k = 1.5
#
#
# Window size: 1 second
# Threshold: [7.199414219551838, 7.551965737880638]
# Accuracy: 0.6170212765957447
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.79      0.55        14
#            1       0.86      0.55      0.67        33
#
#     accuracy                           0.62        47
#    macro avg       0.64      0.67      0.61        47
# weighted avg       0.73      0.62      0.63        47
#
# True Positives (TP): 18 / 33 (Total Real Positives)
# False Positives (FP): 3 / 33 (Total Real Positives)
# True Negatives (TN): 11 / 14 (Total Real Negatives)
# False Negatives (FN): 15 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.833898290566971, 7.173952741204422]
# Accuracy 0.6595744680851063
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.53      0.89      0.66        35
#            1       0.89      0.53      0.66        59
#
#     accuracy                           0.66        94
#    macro avg       0.71      0.71      0.66        94
# weighted avg       0.75      0.66      0.66        94
#
# True Positives (TP): 31 / 59 (Total Real Positives)
# False Positives (FP): 4 / 59 (Total Real Positives)
# True Negatives (TN): 31 / 35 (Total Real Negatives)
# False Negatives (FN): 28 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.726460027416013, 6.204922448142873]
# Accuracy: 0.8742004264392325
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87       206
#            1       0.94      0.83      0.88       263
#
#     accuracy                           0.87       469
#    macro avg       0.87      0.88      0.87       469
# weighted avg       0.88      0.87      0.87       469
#
#
#
# True Positives (TP): 219 / 263 (Total Real Positives)
# False Positives (FP): 15 / 263 (Total Real Positives)
# True Negatives (TN): 191 / 206 (Total Real Negatives)
# False Negatives (FN): 44 / 206 (Total Real Negatives)
#
#
# Threshold for k = 2
#
#
# Window size: 1 second
# Threshold: [7.140655633163704, 7.610724324268772]
# Accuracy: 0.6170212765957447
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      0.93      0.59        14
#            1       0.94      0.48      0.64        33
#
#     accuracy                           0.62        47
#    macro avg       0.69      0.71      0.62        47
# weighted avg       0.79      0.62      0.63        47
#
# True Positives (TP): 16 / 33 (Total Real Positives)
# False Positives (FP): 1 / 33 (Total Real Positives)
# True Negatives (TN): 13 / 14 (Total Real Negatives)
# False Negatives (FN): 17 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.777222548794063, 7.23062848297733]
# Accuracy 0.6276595744680851
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.97      0.66        35
#            1       0.96      0.42      0.59        59
#
#     accuracy                           0.63        94
#    macro avg       0.73      0.70      0.62        94
# weighted avg       0.79      0.63      0.62        94
#
# True Positives (TP): 25 / 59 (Total Real Positives)
# False Positives (FP): 1 / 59 (Total Real Positives)
# True Negatives (TN): 34 / 35 (Total Real Negatives)
# False Negatives (FN): 34 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.646716290628203, 6.284666184930683]
# Accuracy: 0.8528784648187633
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.86       206
#            1       0.99      0.75      0.85       263
#
#     accuracy                           0.85       469
#    macro avg       0.87      0.87      0.85       469
# weighted avg       0.89      0.85      0.85       469
#
#
#
# True Positives (TP): 196 / 263 (Total Real Positives)
# False Positives (FP): 2 / 263 (Total Real Positives)
# True Negatives (TN): 204 / 206 (Total Real Negatives)
# False Negatives (FN): 67 / 206 (Total Real Negatives)
#
#
# Threshold for k = 2.5
#
#
# Window size: 1 second
# Threshold: [7.0818970467755715, 7.669482910656905]
# Accuracy: 0.574468085106383
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        14
#            1       1.00      0.39      0.57        33
#
#     accuracy                           0.57        47
#    macro avg       0.71      0.70      0.57        47
# weighted avg       0.82      0.57      0.57        47
#
# True Positives (TP): 13 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 20 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.7205468070211545, 7.287304224750239]
# Accuracy 0.5957446808510638
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.65        35
#            1       1.00      0.36      0.53        59
#
#     accuracy                           0.60        94
#    macro avg       0.74      0.68      0.59        94
# weighted avg       0.81      0.60      0.57        94
#
# True Positives (TP): 21 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 38 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.566972553840393, 6.364409921718493]
# Accuracy: 0.8102345415778252
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82       206
#            1       0.99      0.67      0.80       263
#
#     accuracy                           0.81       469
#    macro avg       0.85      0.83      0.81       469
# weighted avg       0.86      0.81      0.81       469
#
#
#
# True Positives (TP): 175 / 263 (Total Real Positives)
# False Positives (FP): 1 / 263 (Total Real Positives)
# True Negatives (TN): 205 / 206 (Total Real Negatives)
# False Negatives (FN): 88 / 206 (Total Real Negatives)
#
#
# Threshold for k = 3
#
#
# Window size: 1 second
# Threshold: [7.023138460387438, 7.728241497045039]
# Accuracy: 0.48936170212765956
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        14
#            1       1.00      0.27      0.43        33
#
#     accuracy                           0.49        47
#    macro avg       0.68      0.64      0.48        47
# weighted avg       0.81      0.49      0.46        47
#
# True Positives (TP): 9 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 24 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.663871065248245, 7.343979966523148]
# Accuracy 0.5106382978723404
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.43      1.00      0.60        35
#            1       1.00      0.22      0.36        59
#
#     accuracy                           0.51        94
#    macro avg       0.72      0.61      0.48        94
# weighted avg       0.79      0.51      0.45        94
#
# True Positives (TP): 13 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 46 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.487228817052583, 6.444153658506303]
# Accuracy: 0.7761194029850746
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80       206
#            1       1.00      0.60      0.75       263
#
#     accuracy                           0.78       469
#    macro avg       0.83      0.80      0.77       469
# weighted avg       0.85      0.78      0.77       469
#
#
#
# True Positives (TP): 158 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 105 / 206 (Total Real Negatives)
#
#
# Threshold for k = 3.5
#
#
# Window size: 1 second
# Threshold: [6.964379873999304, 7.787000083433172]
# Accuracy: 0.44680851063829785
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.35      1.00      0.52        14
#            1       1.00      0.21      0.35        33
#
#     accuracy                           0.45        47
#    macro avg       0.68      0.61      0.43        47
# weighted avg       0.81      0.45      0.40        47
#
# True Positives (TP): 7 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 26 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.607195323475337, 7.400655708296056]
# Accuracy 0.46808510638297873
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        35
#            1       1.00      0.15      0.26        59
#
#     accuracy                           0.47        94
#    macro avg       0.71      0.58      0.42        94
# weighted avg       0.78      0.47      0.38        94
#
# True Positives (TP): 9 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 50 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.407485080264774, 6.523897395294112]
# Accuracy: 0.720682302771855
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       206
#            1       1.00      0.50      0.67       263
#
#     accuracy                           0.72       469
#    macro avg       0.81      0.75      0.71       469
# weighted avg       0.83      0.72      0.71       469
#
#
#
# True Positives (TP): 132 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 131 / 206 (Total Real Negatives)
#
#
# Threshold for k = 4
#
#
# Window size: 1 second
# Threshold: [6.905621287611171, 7.845758669821305]
# Accuracy: 0.3829787234042553
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.49        14
#            1       1.00      0.12      0.22        33
#
#     accuracy                           0.38        47
#    macro avg       0.66      0.56      0.35        47
# weighted avg       0.80      0.38      0.30        47
#
# True Positives (TP): 4 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 29 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.550519581702429, 7.457331450068964]
# Accuracy 0.425531914893617
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.39      1.00      0.56        35
#            1       1.00      0.08      0.16        59
#
#     accuracy                           0.43        94
#    macro avg       0.70      0.54      0.36        94
# weighted avg       0.77      0.43      0.31        94
#
# True Positives (TP): 5 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 54 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.327741343476964, 6.603641132081922]
# Accuracy: 0.6780383795309168
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73       206
#            1       1.00      0.43      0.60       263
#
#     accuracy                           0.68       469
#    macro avg       0.79      0.71      0.66       469
# weighted avg       0.81      0.68      0.66       469
#
#
#
# True Positives (TP): 112 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 151 / 206 (Total Real Negatives)
#
#
# Threshold for k = 4.5
#
#
# Window size: 1 second
# Threshold: [6.846862701223038, 7.904517256209439]
# Accuracy: 0.3829787234042553
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.49        14
#            1       1.00      0.12      0.22        33
#
#     accuracy                           0.38        47
#    macro avg       0.66      0.56      0.35        47
# weighted avg       0.80      0.38      0.30        47
#
# True Positives (TP): 4 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 29 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.49384383992952, 7.514007191841873]
# Accuracy 0.4148936170212766
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.39      1.00      0.56        35
#            1       1.00      0.07      0.13        59
#
#     accuracy                           0.41        94
#    macro avg       0.69      0.53      0.34        94
# weighted avg       0.77      0.41      0.29        94
#
# True Positives (TP): 4 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 55 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.247997606689154, 6.683384868869732]
# Accuracy: 0.6311300639658849
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70       206
#            1       1.00      0.34      0.51       263
#
#     accuracy                           0.63       469
#    macro avg       0.77      0.67      0.61       469
# weighted avg       0.80      0.63      0.60       469
#
#
#
# True Positives (TP): 90 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 173 / 206 (Total Real Negatives)
#
#
# Threshold for k = 5
#
#
# Window size: 1 second
# Threshold: [6.788104114834904, 7.9632758425975725]
# Accuracy: 0.3829787234042553
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.49        14
#            1       1.00      0.12      0.22        33
#
#     accuracy                           0.38        47
#    macro avg       0.66      0.56      0.35        47
# weighted avg       0.80      0.38      0.30        47
#
# True Positives (TP): 4 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 29 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.4371680981566115, 7.570682933614782]
# Accuracy 0.4148936170212766
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.39      1.00      0.56        35
#            1       1.00      0.07      0.13        59
#
#     accuracy                           0.41        94
#    macro avg       0.69      0.53      0.34        94
# weighted avg       0.77      0.41      0.29        94
#
# True Positives (TP): 4 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 55 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.168253869901344, 6.763128605657542]
# Accuracy: 0.6012793176972282
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.69       206
#            1       1.00      0.29      0.45       263
#
#     accuracy                           0.60       469
#    macro avg       0.76      0.64      0.57       469
# weighted avg       0.79      0.60      0.55       469
#
#
#
# True Positives (TP): 76 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 187 / 206 (Total Real Negatives)
#
#
# Threshold for k = 5.5
#
#
# Window size: 1 second
# Threshold: [6.729345528446771, 8.022034428985705]
# Accuracy: 0.3829787234042553
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.49        14
#            1       1.00      0.12      0.22        33
#
#     accuracy                           0.38        47
#    macro avg       0.66      0.56      0.35        47
# weighted avg       0.80      0.38      0.30        47
#
# True Positives (TP): 4 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 29 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.380492356383703, 7.62735867538769]
# Accuracy 0.39361702127659576
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        35
#            1       1.00      0.03      0.07        59
#
#     accuracy                           0.39        94
#    macro avg       0.69      0.52      0.31        94
# weighted avg       0.77      0.39      0.25        94
#
# True Positives (TP): 2 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 57 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.088510133113534, 6.842872342445352]
# Accuracy: 0.5650319829424307
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       206
#            1       1.00      0.22      0.37       263
#
#     accuracy                           0.57       469
#    macro avg       0.75      0.61      0.52       469
# weighted avg       0.78      0.57      0.50       469
#
#
#
# True Positives (TP): 59 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 204 / 206 (Total Real Negatives)
#
#
# Threshold for k = 6
#
#
# Window size: 1 second
# Threshold: [6.6705869420586374, 8.080793015373839]
# Accuracy: 0.3617021276595745
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.48        14
#            1       1.00      0.09      0.17        33
#
#     accuracy                           0.36        47
#    macro avg       0.66      0.55      0.32        47
# weighted avg       0.80      0.36      0.26        47
#
# True Positives (TP): 3 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 30 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.323816614610794, 7.684034417160599]
# Accuracy 0.3829787234042553
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        35
#            1       1.00      0.02      0.03        59
#
#     accuracy                           0.38        94
#    macro avg       0.69      0.51      0.29        94
# weighted avg       0.77      0.38      0.22        94
#
# True Positives (TP): 1 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 58 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [5.008766396325724, 6.922616079233162]
# Accuracy: 0.5287846481876333
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.65       206
#            1       1.00      0.16      0.28       263
#
#     accuracy                           0.53       469
#    macro avg       0.74      0.58      0.46       469
# weighted avg       0.77      0.53      0.44       469
#
#
#
# True Positives (TP): 42 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 221 / 206 (Total Real Negatives)
#
#
# Threshold for k = 6.5
#
#
# Window size: 1 second
# Threshold: [6.611828355670504, 8.139551601761973]
# Accuracy: 0.3617021276595745
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.48        14
#            1       1.00      0.09      0.17        33
#
#     accuracy                           0.36        47
#    macro avg       0.66      0.55      0.32        47
# weighted avg       0.80      0.36      0.26        47
#
# True Positives (TP): 3 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 30 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.267140872837886, 7.740710158933507]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.929022659537914, 7.002359816020972]
# Accuracy: 0.511727078891258
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64       206
#            1       1.00      0.13      0.23       263
#
#     accuracy                           0.51       469
#    macro avg       0.74      0.56      0.44       469
# weighted avg       0.77      0.51      0.41       469
#
#
#
# True Positives (TP): 34 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 229 / 206 (Total Real Negatives)
#
#
# Threshold for k = 7
#
#
# Window size: 1 second
# Threshold: [6.55306976928237, 8.198310188150106]
# Accuracy: 0.3404255319148936
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        14
#            1       1.00      0.06      0.11        33
#
#     accuracy                           0.34        47
#    macro avg       0.66      0.53      0.29        47
# weighted avg       0.79      0.34      0.22        47
#
# True Positives (TP): 2 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 31 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.210465131064978, 7.7973859007064155]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.849278922750104, 7.082103552808782]
# Accuracy: 0.488272921108742
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63       206
#            1       1.00      0.09      0.16       263
#
#     accuracy                           0.49       469
#    macro avg       0.73      0.54      0.40       469
# weighted avg       0.76      0.49      0.37       469
#
#
#
# True Positives (TP): 23 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 240 / 206 (Total Real Negatives)
#
#
# Threshold for k = 7.5
#
#
# Window size: 1 second
# Threshold: [6.494311182894237, 8.25706877453824]
# Accuracy: 0.3404255319148936
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47        14
#            1       1.00      0.06      0.11        33
#
#     accuracy                           0.34        47
#    macro avg       0.66      0.53      0.29        47
# weighted avg       0.79      0.34      0.22        47
#
# True Positives (TP): 2 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 31 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.1537893892920685, 7.854061642479325]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.769535185962294, 7.161847289596592]
# Accuracy: 0.47121535181236673
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62       206
#            1       1.00      0.06      0.11       263
#
#     accuracy                           0.47       469
#    macro avg       0.73      0.53      0.37       469
# weighted avg       0.76      0.47      0.33       469
#
#
#
# True Positives (TP): 15 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 248 / 206 (Total Real Negatives)
#
#
# Threshold for k = 8
#
#
# Window size: 1 second
# Threshold: [6.435552596506104, 8.315827360926372]
# Accuracy: 0.3191489361702128
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.47        14
#            1       1.00      0.03      0.06        33
#
#     accuracy                           0.32        47
#    macro avg       0.65      0.52      0.26        47
# weighted avg       0.79      0.32      0.18        47
#
# True Positives (TP): 1 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 32 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [6.09711364751916, 7.910737384252233]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.689791449174484, 7.241591026384402]
# Accuracy: 0.4605543710021322
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.45      1.00      0.62       206
#            1       1.00      0.04      0.07       263
#
#     accuracy                           0.46       469
#    macro avg       0.72      0.52      0.35       469
# weighted avg       0.76      0.46      0.31       469
#
#
#
# True Positives (TP): 10 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 253 / 206 (Total Real Negatives)
#
#
# Threshold for k = 9
#
#
# Window size: 1 second
# Threshold: [6.318035423729837, 8.43334453370264]
# Accuracy: 0.3191489361702128
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.47        14
#            1       1.00      0.03      0.06        33
#
#     accuracy                           0.32        47
#    macro avg       0.65      0.52      0.26        47
# weighted avg       0.79      0.32      0.18        47
#
# True Positives (TP): 1 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 32 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [5.983762163973344, 8.02408886779805]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.530303975598864, 7.401078499960022]
# Accuracy: 0.44776119402985076
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.61       206
#            1       1.00      0.02      0.03       263
#
#     accuracy                           0.45       469
#    macro avg       0.72      0.51      0.32       469
# weighted avg       0.76      0.45      0.29       469
#
#
#
# True Positives (TP): 4 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 259 / 206 (Total Real Negatives)
#
#
# Threshold for k = 9.5
#
#
# Window size: 1 second
# Threshold: [6.259276837341703, 8.492103120090773]
# Accuracy: 0.2978723404255319
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.46        14
#            1       0.00      0.00      0.00        33
#
#     accuracy                           0.30        47
#    macro avg       0.15      0.50      0.23        47
# weighted avg       0.09      0.30      0.14        47
#
# True Positives (TP): 0 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 33 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [5.927086422200435, 8.080764609570958]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.450560238811054, 7.480822236747832]
# Accuracy: 0.44349680170575695
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.61       206
#            1       1.00      0.01      0.02       263
#
#     accuracy                           0.44       469
#    macro avg       0.72      0.50      0.31       469
# weighted avg       0.75      0.44      0.28       469
#
#
#
# True Positives (TP): 2 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 261 / 206 (Total Real Negatives)
#
#
# Threshold for k = 10
#
#
# Window size: 1 second
# Threshold: [6.20051825095357, 8.550861706478907]
# Accuracy: 0.2978723404255319
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.30      1.00      0.46        14
#            1       0.00      0.00      0.00        33
#
#     accuracy                           0.30        47
#    macro avg       0.15      0.50      0.23        47
# weighted avg       0.09      0.30      0.14        47
#
# True Positives (TP): 0 / 33 (Total Real Positives)
# False Positives (FP): 0 / 33 (Total Real Positives)
# True Negatives (TN): 14 / 14 (Total Real Negatives)
# False Negatives (FN): 33 / 14 (Total Real Negatives)
#
#
# Window size: 0.5 second
# Threshold: [5.8704106804275265, 8.137440351343866]
# Accuracy 0.3723404255319149
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        35
#            1       0.00      0.00      0.00        59
#
#     accuracy                           0.37        94
#    macro avg       0.19      0.50      0.27        94
# weighted avg       0.14      0.37      0.20        94
#
# True Positives (TP): 0 / 59 (Total Real Positives)
# False Positives (FP): 0 / 59 (Total Real Positives)
# True Negatives (TN): 35 / 35 (Total Real Negatives)
# False Negatives (FN): 59 / 35 (Total Real Negatives)
#
#
# Window size: 0.1 second
# Threshold: [4.370816502023244, 7.560565973535642]
# Accuracy: 0.44349680170575695
# classification Report
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.61       206
#            1       1.00      0.01      0.02       263
#
#     accuracy                           0.44       469
#    macro avg       0.72      0.50      0.31       469
# weighted avg       0.75      0.44      0.28       469
#
#
#
# True Positives (TP): 2 / 263 (Total Real Positives)
# False Positives (FP): 0 / 263 (Total Real Positives)
# True Negatives (TN): 206 / 206 (Total Real Negatives)
# False Negatives (FN): 261 / 206 (Total Real Negatives)
#
#
# Best k value for window size 1 second: 0.2 with accuracy 0.6808510638297872
# Best k value for window size 0.5 second: 0.1 with accuracy 0.6595744680851063
# Best k value for window size 0.1 second: 1.5 with accuracy 0.8742004264392325
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anwesh/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
data_path = '../../Smart Attack Algorithm/data/Car Hacking Dataset'

benign_data_path = os.path.join(data_path, 'benign_data.csv')
attack_data_path = os.path.join(data_path, 'DoS_dataset.csv')
